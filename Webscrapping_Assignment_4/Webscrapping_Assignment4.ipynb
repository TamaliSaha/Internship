# %% [markdown]
# # Web Scraping Assignment :4
#
# ## Flip Robo Technologies | Internship: 31
#
# ### Submitted By : Tamali Saha (tamali428@gmail.com)

# %%
#import necessary librabies for webscraping with selenium

import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time
import requests
from time import sleep

# %% [markdown]
# ### Q1. Scrape the details of most viewed videos on YouTube from Wikipedia. Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos. You need to find following details: A) Rank B) Name C) Artist D) Upload date E) Views

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

#open the page in automated chrome browser

driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")
time.sleep(2)

# %%
# Creating Empty list to store all the scrapped result
rank =[]
name =[]
artist =[]
upload_date=[]
views=[]

# %%
# Extracting Rank
try:
    rank_tags =driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[1]')
    for i in rank_tags:
        rank.append(i.text.split(".")[0])
except NoSuchElementException:
    rank.append('--')
except StaleElementReferenceException:
    rank.append('--')
    
# Extracting Name
try:
    name_tags =driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[2]')
    for i in name_tags:
        name.append(i.text.split("[")[0])
except NoSuchElementExceptionhElementException:
    name.append('--')
except StaleElementReferenceException:
    name.append('--')

# Extracting Artist
try:
    artist_tags =driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
    for i in artist_tags:
        artist.append(i.text)
except NoSuchElementExceptionhElementException:
    artist.append('--')
except StaleElementReferenceException:
    artist.append('--')
    
# Extracting Upload date 
try:
    upload_date_tags =driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
    for i in upload_date_tags:
        upload_date.append(i.text)
except NoSuchElementExceptionhElementException:
    upload_date.append('--')
except StaleElementReferenceException:
    upload_date.append('--')
    
    
# Extracting Views
try:
    views_tags=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
    for i in views_tags :
        views.append(i.text)
except NoSuchElementExceptionhElementException:
    views.append('--')
except StaleElementReferenceException:
    views.append('--')

# %%
print(len(rank))
print(len(name))
print(len(artist))
print(len(upload_date))
print(len(views))
# Out:
# 30
# 30
# 30
# 30
# 30

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(rank, name,artist, upload_date,views ))

data= pd.DataFrame(data_list, 
    columns =['Rank', 'Name','Artist', 'Upload_date','Views '],
    index=pd.RangeIndex(start=1, stop=31, name='Sr. No.'))

#Print the required data

print ("Details of most viewed videos on YouTube from Wikipedia:\n")
data
# Out:
# Details of most viewed videos on YouTube from Wikipedia:
#         Rank                                         Name  \
# Sr. No.
# 1          1                           "Baby Shark Dance"
# 2          2                                  "Despacito"
# 3          3                       "Johny Johny Yes Papa"
# 4          4                               "Shape of You"
# 5          5                              "See You Again"
# 6          6                                  "Bath Song"
# 7          7                "Phonics Song with Two Words"
# 8          8                                "Uptown Funk"
# 9          9  "Learning Colors – Colorful Eggs on a Farm"
# 10        10                              "Gangnam Style"
# 11        11   "Masha and the Bear – Recipe for Disaster"
# 12        12                          "Wheels on the Bus"
# 13        13                             "Dame Tu Cosita"
# 14        14                                      "Sugar"
# 15        15                                       "Roar"
# 16        16                             "Counting Stars"
# 17        17                                      "Sorry"
# 18        18                                     "Axel F"
# 19        18                          "Thinking Out Loud"
# 20        20                        "Baa Baa Black Sheep"
# 21        21                                 "Dark Horse"
# 22        22                                      "Faded"
# 23        23                             "Girls Like You"
# 24        24                                 "Let Her Go"
# 25        25                                   "Bailando"
# 26        26                                    "Lean On"
# 27        27                                    "Perfect"
# 28        28           "Waka Waka (This Time for Africa)"
# 29        29                               "Shake It Off"
# 30        30          "Humpty the train on a fruits ride"
#
#                                                 Artist        Upload_date  \
# Sr. No.
# 1          Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016
# 2                                           Luis Fonsi   January 12, 2017
# 3                                          LooLoo Kids    October 8, 2016
# 4                                           Ed Sheeran   January 30, 2017
# 5                                          Wiz Khalifa      April 6, 2015
# 6                           Cocomelon – Nursery Rhymes        May 2, 2018
# 7                                            ChuChu TV      March 6, 2014
# 8                                          Mark Ronson  November 19, 2014
# 9                                          Miroshka TV  February 27, 2018
# 10                                                 Psy      July 15, 2012
# 11                                          Get Movies   January 31, 2012
# 12                          Cocomelon – Nursery Rhymes       May 24, 2018
# 13                                           El Chombo      April 5, 2018
# 14                                            Maroon 5   January 14, 2015
# 15                                          Katy Perry  September 5, 2013
# 16                                         OneRepublic       May 31, 2013
# 17                                       Justin Bieber   October 22, 2015
# 18                                          Crazy Frog      June 16, 2009
# 19                                          Ed Sheeran    October 7, 2014
# 20                          Cocomelon – Nursery Rhymes      June 25, 2018
# 21                                          Katy Perry  February 20, 2014
# 22                                         Alan Walker   December 3, 2015
# 23                                            Maroon 5       May 31, 2018
# 24                                           Passenger      July 25, 2012
# 25                                    Enrique Iglesias     April 11, 2014
# 26                                         Major Lazer     March 22, 2015
# 27                                          Ed Sheeran   November 9, 2017
# 28                                             Shakira       June 4, 2010
# 29                                        Taylor Swift    August 18, 2014
# 30       Kiddiestv Hindi – Nursery Rhymes & Kids Songs   January 26, 2018
#
#         Views
# Sr. No.
# 1        11.40
# 2         7.98
# 3         6.47
# 4         5.81
# 5         5.64
# 6         5.63
# 7         4.90
# 8         4.70
# 9         4.65
# 10        4.55
# 11        4.51
# 12        4.40
# 13        4.07
# 14        3.76
# 15        3.66
# 16        3.65
# 17        3.59
# 18        3.52
# 19        3.50
# 20        3.38
# 21        3.35
# 22        3.34
# 23        3.33
# 24        3.30
# 25        3.27
# 26        3.26
# 27        3.26
# 28        3.25
# 29        3.21
# 30        3.17

# %% [markdown]
# ### Q2. 2. Scrape the details team India’s international fixtures from bcci.tv. Url = https://www.bcci.tv/. You need to find following details: A) Match title (I.e. 1st ODI) B) Series C) Place D) Date E) Time .
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

#open the page in automated chrome browser

driver.get("https://www.bcci.tv/")
time.sleep(2)

# %%
# Opening fixtures

international =driver.find_element(By.XPATH,'//div[@class="collapse navbar-collapse"]/ul/li[2]/a')
try:
    international.click()
except ElementNotInteractableException:
    driver.get(international.get_attribute('href'))

# %%
# Creating empty list to store all the scrapped result
title = []
series = []
place = []
date = []
time = []
url=[]

# %%
# Extracting title
try:
    title_tags=driver.find_elements(By.XPATH,'//span[@class="ng-binding"]')
    for i in title_tags :
        title.append(i.text)
except StaleElementReferenceException:
    title.append('--')
title
# Out:
# ['SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23',
#  'ASIA CUP WOMENS 2022',
#  'ASIA CUP WOMENS 2022',
#  'SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23',
#  'ASIA CUP WOMENS 2022',
#  'SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23']

# %%
# Extracting series
try:
    series_tags=driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]')
    for i in series_tags :
        series.append(i.text.split("-")[0])
except StaleElementReferenceException:
    series.append('--')
series
# Out:
# ['1st ODI ', '4th T20I ', '5th T20I ', '2nd ODI ', '6th T20I ', '3rd ODI ']

# %%
# Extracting place
try:
    place_tags=driver.find_elements(By.XPATH,'//span[@class="ng-binding ng-scope"]')
    for i in place_tags :
        place.append(i.text.replace(','," "))
except StaleElementReferenceException:
    place.append('--')
place
# Out:
# ['Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium ',
#  'Sylhet International Cricket Stadium ',
#  'Sylhet International Cricket Stadium ',
#  'JSCA International Stadium Complex ',
#  'Sylhet International Cricket Stadium ',
#  'Arun Jaitley Stadium ']

# %%
# Extracting date
try:
    date_tags=driver.find_elements(By.XPATH,'//h5[@class="ng-binding"]')
    for i in date_tags :
        date.append(i.text)
except StaleElementReferenceException:
    date.append('--')
date
# Out:
# ['6 OCT 2022',
#  '7 OCT 2022',
#  '8 OCT 2022',
#  '9 OCT 2022',
#  '10 OCT 2022',
#  '11 OCT 2022']

# %%
# Extracting time
try:
    time_tags=driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]')
    for i in time_tags :
        time.append(i.text)
except StaleElementReferenceException:
    time.append('--')
time
# Out:
# ['1:30 PM IST',
#  '1:00 PM IST',
#  '1:00 PM IST',
#  '1:30 PM IST',
#  '1:00 PM IST',
#  '1:30 PM IST']

# %%
# Extracting url
url_tags=driver.find_elements(By.XPATH,'//a[@class="match-center-btn ng-scope"]')
for i in url_tags :
    url.append(i.get_attribute('href'))

# %%
url
# Out:
# ['https://www.bcci.tv/events/82/south-africa-tour-of-india-odi-series-2022-23/match/642/1st-odi',
#  'https://www.bcci.tv/events/86/asia-cup-womens-2022/match/682/4th-t20i',
#  'https://www.bcci.tv/events/86/asia-cup-womens-2022/match/684/5th-t20i',
#  'https://www.bcci.tv/events/82/south-africa-tour-of-india-odi-series-2022-23/match/643/2nd-odi',
#  'https://www.bcci.tv/events/86/asia-cup-womens-2022/match/683/6th-t20i',
#  'https://www.bcci.tv/events/82/south-africa-tour-of-india-odi-series-2022-23/match/644/3rd-odi']

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(title,series,place, date,time,url ))

data= pd.DataFrame(data_list, 
    columns =['Title', 'Series','Place', 'Date','Time ', 'URL'])

#Print the required data

print ("Details team India’s international fixtures from bcci.tv.:\n")
data
# Out:
# Details team India’s international fixtures from bcci.tv.:
#                                            Title     Series  \
# 0  SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23   1st ODI
# 1                           ASIA CUP WOMENS 2022  4th T20I
# 2                           ASIA CUP WOMENS 2022  5th T20I
# 3  SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23   2nd ODI
# 4                           ASIA CUP WOMENS 2022  6th T20I
# 5  SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23   3rd ODI
#
#                                                Place         Date  \
# 0  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...   6 OCT 2022
# 1              Sylhet International Cricket Stadium    7 OCT 2022
# 2              Sylhet International Cricket Stadium    8 OCT 2022
# 3                JSCA International Stadium Complex    9 OCT 2022
# 4              Sylhet International Cricket Stadium   10 OCT 2022
# 5                              Arun Jaitley Stadium   11 OCT 2022
#
#          Time                                                 URL
# 0  1:30 PM IST  https://www.bcci.tv/events/82/south-africa-tou...
# 1  1:00 PM IST  https://www.bcci.tv/events/86/asia-cup-womens-...
# 2  1:00 PM IST  https://www.bcci.tv/events/86/asia-cup-womens-...
# 3  1:30 PM IST  https://www.bcci.tv/events/82/south-africa-tou...
# 4  1:00 PM IST  https://www.bcci.tv/events/86/asia-cup-womens-...
# 5  1:30 PM IST  https://www.bcci.tv/events/82/south-africa-tou...

# %% [markdown]
# ### Q3. Scrape the details of selenium exception from guru99.com. Url = https://www.guru99.com/ You need to find following details: A) Name B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

#open the page in automated chrome browser

driver.get("https://www.guru99.com/")
time.sleep(2)

# %%
# Selecting Selenium option

selenium=driver.find_element(By.XPATH,'//div[@class="featured-box cloumnsize1"]/ul[1]/li[3]/a')
try:
    selenium.click()
except ElementNotInteractableException:
    driver.get(selenium.get_attribute('href'))

# %%
# Selecting Selenium exception

exceptation =driver.find_element(By.XPATH,'//*[@id="post-193"]/div/div/table[5]/tbody/tr[34]/td[1]/a')
try:
    exceptation.click()
    time.sleep(2)
except ElementNotInteractableException:
    driver.get(exceptation.get_attribute('href'))
    time.sleep(2)

# %%
# Creating Empty list to store all the scrapped result
name =[]
description=[]

# %%
# Extracting name and description of exception
all_info=[]
try:
    all_tags =driver.find_elements(By.XPATH,'//div[@class="entry-content single-content"]/p')
    for i in all_tags:
        all_info.append(i.text.split(":"))
except NoSuchElementException:
    all_info.append('--')
all_info1= all_info[:41]

jj=[]
for i in all_info1:
    for j in i:
        jj.append(j)
        

for i in range(0, len(jj)):
    if i % 2 ==0:
        name.append(jj[i])

for i in range(0, len(jj)):
    if i % 2 ==1:
        description.append(jj[i])

# %%
print(len(name))
print(len(description))
# Out:
# 41
# 41

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(name,description ))

data= pd.DataFrame(data_list, 
    columns =['Name','Description'],
    index=pd.RangeIndex(start=1, stop=42, name='Sr. No.'))

#Print the required data

print ("Details of selenium exception from guru99.com:\n")
data
# Out:
# Details of selenium exception from guru99.com:
#                                             Name  \
# Sr. No.
# 1                  1. ElementNotVisibleException
# 2               2. ElementNotSelectableException
# 3                      3. NoSuchElementException
# 4                        4. NoSuchFrameException
# 5                     5. NoAlertPresentException
# 6                       6. NoSuchWindowException
# 7              7. StaleElementReferenceException
# 8                    8. SessionNotFoundException
# 9                            9. TimeoutException
# 10                        10. WebDriverException
# 11                 11. ConnectionClosedException
# 12          12. ElementClickInterceptedException
# 13           13. ElementNotInteractableException
# 14                  14. ErrorInResponseException
# 15       15. ErrorHandler.UnknownServerException
# 16              16. ImeActivationFailedException
# 17                  17. ImeNotAvailableException
# 18              18. InsecureCertificateException
# 19                  19. InvalidArgumentException
# 20              20. InvalidCookieDomainException
# 21               21. InvalidCoordinatesException
# 22              22. InvalidElementStateException
# 23                 23. InvalidSessionIdException
# 24            24. InvalidSwitchToTargetException
# 25                       25. JavascriptException
# 26                             26. JsonException
# 27                  27. NoSuchAttributeException
# 28            28. MoveTargetOutOfBoundsException
# 29                    29. NoSuchContextException
# 30                     30. NoSuchCookieException
# 31                         31. NotFoundException
# 32               32. RemoteDriverServerException
# 33                       33. ScreenshotException
# 34                34. SessionNotCreatedException
# 35                35. UnableToSetCookieException
# 36                36. UnexpectedTagNameException
# 37                   37. UnhandledAlertException
# 38           38. UnexpectedAlertPresentException
# 39                    39. UnknownMethodException
# 40               40. UnreachableBrowserException
# 41               41. UnsupportedCommandException
#
#                                                Description
# Sr. No.
# 1         This type of Selenium exception occurs when a...
# 2         This Selenium exception occurs when an elemen...
# 3         This Exception occurs if an element could not...
# 4         This Exception occurs if the frame target to ...
# 5         This Exception occurs when you switch to no p...
# 6         This Exception occurs if the window target to...
# 7         This Selenium exception occurs happens when t...
# 8         The WebDriver is acting after you quit the br...
# 9         Thrown when there is not enough time for a co...
# 10        This Exception takes place when the WebDriver...
# 11        This type of Exception takes place when there...
# 12        The command may not be completed as the eleme...
# 13        This Selenium exception is thrown when any el...
# 14        This happens while interacting with the Firef...
# 15        Exception is used as a placeholder in case if...
# 16        This expectation will occur when IME engine a...
# 17         It takes place when IME support is unavailable.
# 18        Navigation made the user agent to hit a certi...
# 19        It occurs when an argument does not belong to...
# 20        This happens when you try to add a cookie und...
# 21        This type of Exception matches an interacting...
# 22        It occurs when command can’t be finished when...
# 23        This Exception took place when the given sess...
# 24        This occurs when the frame or window target t...
# 25        This issue occurs while executing JavaScript ...
# 26        It occurs when you afford to get the session ...
# 27        This kind of Exception occurs when the attrib...
# 28        It takes place if the target provided to the ...
# 29                ContextAware does mobile device testing.
# 30        This Exception occurs when no cookie matching...
# 31        This Exception is a subclass of WebDriverExce...
# 32        This Selenium exception is thrown when the se...
# 33                 It is not possible to capture a screen.
# 34        It happens when a new session could not be su...
# 35        This occurs if a driver is unable to set a co...
# 36        Happens if a support class did not get a web ...
# 37        This expectation occurs when there is an aler...
# 38        It occurs when there is the appearance of an ...
# 39        This Exception happens when the requested com...
# 40        This Exception occurs only when the browser i...
# 41        This occurs when remote WebDriver doesn’t sen...

# %% [markdown]
# ### Q4.  Scrape the details of State-wise GDP of India from statisticstime.com. Url = http://statisticstimes.com/ You have to find following details: A) Rank B) State C) GSDP(19-20)  D) GSDP (18-19) E) Share  (18-19) F) GDP (billion)
# Note: - From statisticstimes home page you have to reach to economy page through code

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

#open the page in automated chrome browser

driver.get("http://statisticstimes.com/")
time.sleep(2)

# %%
# Clicking on ecomony tab

India=driver.find_element(By.XPATH,'//div[@class="dropdown"][2]/button')
try:
    India.click()
except ElementNotInteractableException:
    driver.get(India.get_attribute('href'))  
time.sleep(2)

# %%
# Clicking on India from economy tab
state = driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
driver.get(state.get_attribute('href'))
time.sleep(2)

# %%
# Clicking on GDP of Indian state

state = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
driver.get(state.get_attribute('href'))
time.sleep(2)

# %%
# Creating empty lists to store all the scrapped result
rank =[]
state =[]
gsdp_19_20=[]
gsdp_18_19 =[]
share_18_19 =[]
GDP =[]

# %%
# Extracting Rank 
try:
    rank_tags =driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[1]')
    for i in rank_tags :
        rank.append(i.text)
except NoSuchElementException:
    rank.append('NA')
    
# Extracting state name
try:
    state_tags =driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[2]')
    for i in state_tags:
        state.append(i.text)
except NoSuchElementException:
    state.append('NA')
    
# Extracting GDSP 19-20
try:
    gsdp_19_20_tags =driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[3]')
    for i in gsdp_19_20_tags:
        gsdp_19_20.append(i.text)
except NoSuchElementException:
    gsdp_19_20.append('NA')
    
# Extracting GDSP 18-19
try:
    gsdp_18_19_tags =driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[4]')
    for i in gsdp_18_19_tags:
        gsdp_18_19.append(i.text)
except NoSuchElementException:
    gsdp_18_19.append('NA')
    
# Extracting Share 18_19
try:
    share_18_19_tags =driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[5]')
    for i in share_18_19_tags:
        share_18_19.append(i.text)
except NoSuchElementException:
    share_18_19.append('NA')
    
# Extracting GDP
try:
    GDP_tags =driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[6]')
    for i in GDP_tags:
        GDP.append(i.text)
except NoSuchElementException:
    GDP.append('NA')

# %%
print(len(rank))
print(len(state))
print(len(gsdp_19_20))
print(len(gsdp_18_19))
print(len(share_18_19))
print(len(GDP))
# Out:
# 33
# 33
# 33
# 33
# 33
# 33

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(rank, state,gsdp_19_20, gsdp_18_19,share_18_19 , GDP))

data= pd.DataFrame(data_list, 
    columns =['Rank', 'State', 'GSDP_19_20','GSDP_18_19','Share_18_19' , 'GDP'],
                index=pd.RangeIndex(start=1, stop=34, name='Sr. No.'))

#Print the required data

print ("Details of State-wise GDP of India from statisticstime.com:\n")
data
# Out:
# Details of State-wise GDP of India from statisticstime.com:
#         Rank                      State GSDP_19_20 GSDP_18_19 Share_18_19  \
# Sr. No.
# 1          1                Maharashtra          -  2,632,792      13.94%
# 2          2                 Tamil Nadu  1,845,853  1,630,208       8.63%
# 3          3              Uttar Pradesh  1,687,818  1,584,764       8.39%
# 4          4                    Gujarat          -  1,502,899       7.96%
# 5          5                  Karnataka  1,631,977  1,493,127       7.91%
# 6          6                West Bengal  1,253,832  1,089,898       5.77%
# 7          7                  Rajasthan  1,020,989    942,586       4.99%
# 8          8             Andhra Pradesh    972,782    862,957       4.57%
# 9          9                  Telangana    969,604    861,031       4.56%
# 10        10             Madhya Pradesh    906,672    809,592       4.29%
# 11        11                     Kerala          -    781,653       4.14%
# 12        12                      Delhi    856,112    774,870       4.10%
# 13        13                    Haryana    831,610    734,163       3.89%
# 14        14                      Bihar    611,804    530,363       2.81%
# 15        15                     Punjab    574,760    526,376       2.79%
# 16        16                     Odisha    521,275    487,805       2.58%
# 17        17                      Assam          -    315,881       1.67%
# 18        18               Chhattisgarh    329,180    304,063       1.61%
# 19        19                  Jharkhand    328,598    297,204       1.57%
# 20        20                Uttarakhand          -    245,895       1.30%
# 21        21            Jammu & Kashmir          -    155,956       0.83%
# 22        22           Himachal Pradesh    165,472    153,845       0.81%
# 23        23                        Goa     80,449     73,170       0.39%
# 24        24                    Tripura     55,984     49,845       0.26%
# 25        25                 Chandigarh          -     42,114       0.22%
# 26        26                 Puducherry     38,253     34,433       0.18%
# 27        27                  Meghalaya     36,572     33,481       0.18%
# 28        28                     Sikkim     32,496     28,723       0.15%
# 29        29                    Manipur     31,790     27,870       0.15%
# 30        30                   Nagaland          -     27,283       0.14%
# 31        31          Arunachal Pradesh          -     24,603       0.13%
# 32        32                    Mizoram     26,503     22,287       0.12%
# 33        33  Andaman & Nicobar Islands          -          -           -
#
#              GDP
# Sr. No.
# 1        399.921
# 2        247.629
# 3        240.726
# 4        228.290
# 5        226.806
# 6        165.556
# 7        143.179
# 8        131.083
# 9        130.791
# 10       122.977
# 11       118.733
# 12       117.703
# 13       111.519
# 14        80.562
# 15        79.957
# 16        74.098
# 17        47.982
# 18        46.187
# 19        45.145
# 20        37.351
# 21        23.690
# 22        23.369
# 23        11.115
# 24         7.571
# 25         6.397
# 26         5.230
# 27         5.086
# 28         4.363
# 29         4.233
# 30         4.144
# 31         3.737
# 32         3.385
# 33             -

# %% [markdown]
# ### Q5. Scrape the details of trending repositories on Github.com. Url = https://github.com/You have to find the following details:A) Repository title B) Repository description C) Contributors count D) Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

#open the page in automated chrome browser

driver.get("https://github.com/You")
time.sleep(2)

# %%
# Clicking on button tab

button =driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a')
driver.get(button.get_attribute('href'))
time.sleep(2)

# %%
# Creating Empty list for Scraping Data
title=[]
description=[]
count =[]
language =[]
url=[]

# %%
# Extracting Share 18_19
try:
    title_tags =driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]')
    for i in title_tags:
        title.append(i.text)
except NoSuchElementException:
    title.append('NA')

# %%
len(title)
# Out:
# 25

# %%
# Extracting URL

try:
    url_tags =driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]/a')
    for i in url_tags:
        url.append(i.get_attribute("href"))
except NoSuchElementException:
    url.append('NA')
len(url)
# Out:
# 25

# %%
for i in url:
    driver.get(i)
    time.sleep(1)
    
    try:
        description_tags=driver.find_element(By.XPATH,'/html/body/div[4]/div/main/turbo-frame/div/div/div/div[3]/div[2]/div/div[1]/div/p')
        description.append(description_tags.text)
    except NoSuchElementException:
        description.append('NA')

# %%
len(description)
# Out:
# 25

# %%
for i in url:
    driver.get(i)
    time.sleep(1)
    
    try:
        count_tags=driver.find_element(By.XPATH, "//h2[@class='h4 mb-3']/a[contains(text(),'Contributors')]/span")
        count.append(count_tags.text)
    except NoSuchElementException:
        count.append('NA')

# %%
len(count)
# Out:
# 25

# %%
for i in url:
    driver.get(i)
    time.sleep(1)

    # Scraping Language
    L =[]
    try:
        language_tag =driver.find_elements(By.XPATH,"//li[@class='d-inline']//a//span[1]")
        if language_tag:
            for j in language_tag:
                L.append(j.text)
        else:
            L.append('NA')
        language.append(L)
    except NoSuchElementException:
        language.append('NA')

# %%
len(language)
# Out:
# 25

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(title,description,count,language,url ))

data= pd.DataFrame(data_list, 
    columns =['Title', 'Description', 'Count','Language','URL'],
                  index=pd.RangeIndex(start=1, stop=26, name='Sr. No.'))

#Print the required data

print ("Details of trending repositories on Github.com:\n")
data
# Out:
# Details of trending repositories on Github.com:
#                                                      Title  \
# Sr. No.
# 1         total-typescript / beginners-typescript-tutorial
# 2                                          penpot / penpot
# 3                                     cypress-io / cypress
# 4                                      google / googletest
# 5                        lucidrains / make-a-video-pytorch
# 6                      NielsRogge / Transformers-Tutorials
# 7                                         nv-tlabs / GET3D
# 8        inspiradanacomputacao / tecnologistas-contra-b...
# 9                                  Ildaron / Laser_control
# 10          developedbyed / react-portofolio-with-tailwind
# 11                       Nickyie / Cybersecurity-Resources
# 12                                         isaced / V2exOS
# 13                                   IceWhaleTech / CasaOS
# 14                            Asabeneh / 30-Days-Of-Python
# 15                                    google / latexify_py
# 16                                         denoland / deno
# 17                              phoenixframework / phoenix
# 18                       microsoft / Web-Dev-For-Beginners
# 19                              CompVis / stable-diffusion
# 20                               fireship-io / fireship.io
# 21                                  lidangzzz / How-to-run
# 22                                           novuhq / novu
# 23                                docker / awesome-compose
# 24                        Asabeneh / 30-Days-Of-JavaScript
# 25                                        dosisod / refurb
#
#                                                Description  Count  \
# Sr. No.
# 1         An interactive TypeScript tutorial for beginners     12
# 2        Penpot - The Open-Source design & prototyping ...     78
# 3        Fast, easy and reliable testing for anything t...    395
# 4        GoogleTest - Google Testing and Mocking Framework    369
# 5        Implementation of Make-A-Video, new SOTA text ...     NA
# 6        This repository contains demos I made with the...      3
# 7                                                       NA     NA
# 8        Manifesto de Pessoas Tecnologistas contra Bols...    126
# 9        Open-Source Laser for control mosquito, weed, ...     NA
# 10                                                      NA     NA
# 11            A Library of various cybersecurity resources      2
# 12                    一个用 SwiftUI 编写的 V2ex macOS 客户端（Beta）      2
# 13       CasaOS - A simple, easy-to-use, elegant open-s...      9
# 14       30 days of Python programming challenge is a s...      7
# 15       Generates LaTeX math description from Python f...      6
# 16         A modern runtime for JavaScript and TypeScript.    747
# 17              Peace of mind from prototype to production  1,075
# 18       24 Lessons, 12 Weeks, Get Started as a Web Dev...    149
# 19                  A latent text-to-image diffusion model      7
# 20       Build and ship your app faster https://fireshi...    198
# 21                          立党老师的润学（零基础转码/移民/留学/海外创业/永居）笔记     NA
# 22       🚀 The open-source notifications infrastructure...    102
# 23                          Awesome Docker Compose samples     60
# 24       30 days of JavaScript programming challenge is...     31
# 25       A tool for refurbishing and modernizing Python...      3
#
#                                                   Language  \
# Sr. No.
# 1                                 [TypeScript, JavaScript]
# 2        [Clojure, SCSS, JavaScript, HTML, Shell, Docke...
# 3           [JavaScript, TypeScript, Vue, HTML, SCSS, CSS]
# 4                                     [C++, Python, CMake]
# 5                                                 [Python]
# 6                                       [Jupyter Notebook]
# 7                                      [Python, Cuda, C++]
# 8                                                     [NA]
# 9                                       [Python, Makefile]
# 10                                       [JavaScript, CSS]
# 11                                                    [NA]
# 12                                                 [Swift]
# 13                                   [Go, Shell, Makefile]
# 14                                     [Python, CSS, HTML]
# 15                                                [Python]
# 16                          [Rust, JavaScript, TypeScript]
# 17       [Elixir, JavaScript, HTML, CSS, Euphoria, Eart...
# 18                            [JavaScript, HTML, CSS, Vue]
# 19                       [Jupyter Notebook, Python, Shell]
# 20            [Svelte, HTML, TypeScript, SCSS, JavaScript]
# 21                                                    [NA]
# 22       [TypeScript, JavaScript, HTML, Handlebars, EJS...
# 23        [HTML, Dockerfile, TypeScript, Java, Python, C#]
# 24                                      [JavaScript, HTML]
# 25                                                [Python]
#
#                                                        URL
# Sr. No.
# 1        https://github.com/total-typescript/beginners-...
# 2                         https://github.com/penpot/penpot
# 3                    https://github.com/cypress-io/cypress
# 4                     https://github.com/google/googletest
# 5        https://github.com/lucidrains/make-a-video-pyt...
# 6        https://github.com/NielsRogge/Transformers-Tut...
# 7                        https://github.com/nv-tlabs/GET3D
# 8        https://github.com/inspiradanacomputacao/tecno...
# 9                 https://github.com/Ildaron/Laser_control
# 10       https://github.com/developedbyed/react-portofo...
# 11       https://github.com/Nickyie/Cybersecurity-Resou...
# 12                        https://github.com/isaced/V2exOS
# 13                  https://github.com/IceWhaleTech/CasaOS
# 14           https://github.com/Asabeneh/30-Days-Of-Python
# 15                   https://github.com/google/latexify_py
# 16                        https://github.com/denoland/deno
# 17             https://github.com/phoenixframework/phoenix
# 18       https://github.com/microsoft/Web-Dev-For-Begin...
# 19             https://github.com/CompVis/stable-diffusion
# 20              https://github.com/fireship-io/fireship.io
# 21                 https://github.com/lidangzzz/How-to-run
# 22                          https://github.com/novuhq/novu
# 23               https://github.com/docker/awesome-compose
# 24       https://github.com/Asabeneh/30-Days-Of-JavaScript
# 25                       https://github.com/dosisod/refurb

# %% [markdown]
# ### Q 6. Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/ You have to find the following details: A) Song name B) Artist name C) Last week rank D) Peak rank E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

#open the page in automated chrome browser

driver.get(" https:/www.billboard.com/")
time.sleep(2)

# %%
# Clicking on button tab

button =driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a')
driver.get(button.get_attribute('href'))
time.sleep(2)

# %%
# Clicking on hot100 tab

hot100 =driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[3]/div/nav/ul/li[1]/a')
driver.get(hot100.get_attribute('href'))
time.sleep(2)

# %%
# Creating Empty List for scrapped datas

name =[]
artist =[]
rank=[]
peak_rank =[]
weeks =[]
all_info=[]

# %%
# Scraping Song Name
try:
    song_tags =driver.find_elements(By.XPATH,'//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]/li/h3')
    for i in song_tags:
        name.append(i.text)
except NoSuchElementException:
    name.append('NA')

# %%
len(name)
# Out:
# 100

# %%
all_info=[]
try:
    all_tags =driver.find_elements(By.XPATH,'//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]/li/span')
    for i in all_tags:
        all_info.append(i.text)
except NoSuchElementException:
    all_info.append('NA')

# %%
# Scraping artist
artist= all_info[0:401:4]
len(artist)
# Out:
# 100

# %%
# Scraping rank
rank= all_info[1:401:4]
len(rank)
# Out:
# 100

# %%
# Scraping rank
peak_rank= all_info[2:401:4]
len(peak_rank)
# Out:
# 100

# %%
# Scraping weeks
weeks= all_info[3:401:4]
len(weeks)
# Out:
# 100

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(name,artist,rank,peak_rank,weeks ))

data= pd.DataFrame(data_list, 
    columns =['Song_name', 'Artist_name', 'Last_week_rank','Peak_rank','Weeks on board'],
                  index=pd.RangeIndex(start=1, stop=101, name='This_week_rank'))

#Print the required data

print ("Details of top 100 songs on billiboard.com.:\n")
data
# Out:
# Details of top 100 songs on billiboard.com.:
#                                   Song_name                     Artist_name  \
# This_week_rank
# 1                                 As It Was                    Harry Styles
# 2                                 Bad Habit                      Steve Lacy
# 3               I Like You (A Happier Song)  Post Malone Featuring Doja Cat
# 4                                   Sunroof              Nicky Youre & dazy
# 5                         Super Freaky Girl                     Nicki Minaj
# ...                                     ...                             ...
# 96                  Thought You Should Know                   Morgan Wallen
# 97                            Where It Ends                Bailey Zimmerman
# 98                         Backstage Passes   EST Gee Featuring Jack Harlow
# 99                                     Snap                       Rosa Linn
# 100                           Beat The Odds                        Lil Tjay
#
#                Last_week_rank Peak_rank Weeks on board
# This_week_rank
# 1                           1         1             25
# 2                           2         2             12
# 3                           5         3             16
# 4                           4         4             17
# 5                           3         1              6
# ...                       ...       ...            ...
# 96                         98        12             20
# 97                         93        32              5
# 98                          -        98              1
# 99                         97        93              4
# 100                        91        36              4
#
# [100 rows x 5 columns]

# %% [markdown]
# ### Q7.Scrape the details of Data science recruiters from naukri.com. Url = https://www.naukri.com/. You have to find the following details: A) Name B) Designation C) Company D) Skills they hire for E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
#First connect to the driver

driver= webdriver.Chrome(r"chromedriver.exe")

#open the page in automated chrome browser

driver.get("https://www.naukri.com/data-science-recruiters")

# %%
# Creating Empty List for scrapped datas
name=[] 
designation=[] 
company=[] 
skills=[]
url=[]

# %%
# Scraping name
try:
    name_tags =driver.find_elements(By.XPATH,'//span[@class="fl ellipsis"]')
    for i in name_tags:
        name.append(i.text)
except NoSuchElementException:
    name.append('NA')

# %%
len(name)
# Out:
# 50

# %%
# Scraping designation
try:
    des_tags =driver.find_elements(By.XPATH,'//span[@class="ellipsis clr"]')
    for i in des_tags:
        designation.append(i.text)
except NoSuchElementException:
    designation.append('NA')

# %%
len(designation)
# Out:
# 50

# %%
# Scraping company
comp=[]
try:
    com_tags =driver.find_elements(By.XPATH,'//a[@class="ellipsis"]')
    for i in com_tags:
        comp.append(i.text)
except NoSuchElementException:
    comp.append('NA')
    
for i in range(0, len(comp)):
    if i %2==1:
        company.append(comp[i])

# %%
len(company)
# Out:
# 50

# %%
# Scraping skills
try:
    skills_tags =driver.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]')
    for i in skills_tags:
        skills.append(i.text)
except NoSuchElementException:
    skills.append('NA')

# %%
len(skills)
# Out:
# 50

# %%
# Scraping url
try:
    url_tags =driver.find_elements(By.XPATH,'//div[@class="recImg mid_pImg_Silht"]/a')
    for i in url_tags:
        url.append(i.get_attribute("href"))
except NoSuchElementException:
    url.append('NA')

# %%
len(url)
# Out:
# 50

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(name,designation,company,skills,url))

data= pd.DataFrame(data_list, 
    columns =['Name', 'Designation', 'Company','Skills','URL'],
                  index=pd.RangeIndex(start=1, stop=51, name='Sr No'))

#Print the required data

print ("Details of Data science recruiters from naukri.com:\n")
data
# Out:
# Details of Data science recruiters from naukri.com:
#                                                 Name  \
# Sr No
# 1                                       Aakash Harit
# 2                               shravan Kumar Gaddam
# 3                           MARSIAN Technologies LLP
# 4                                       Anik Agrawal
# 5                                       subhas patel
# 6       Abhishek - Only Analytics Hiring - India and
# 7      Institute for Financial Management and Resear
# 8                                        Balu Ramesh
# 9                                      Asif Lucknowi
# 10                                   InstaFinancials
# 11                                Mahesh Babu Channa
# 12                                    Priyanka Akiri
# 13                                   Kalpana Dumpala
# 14                                           Mubarak
# 15                                    Kushal Rastogi
# 16                                Vaishnavi Kudalkar
# 17                                      Kapil Devang
# 18                                   Sakshi Chhikara
# 19                                       Ruchi Dhote
# 20                                     Manisha Yadav
# 21                                       Riya Rajesh
# 22                              Rashmi Bhattacharjee
# 23                                     Faizan Kareem
# 24                                    Rithika dadwal
# 25                                Sandhya Khandagale
# 26                                         Shaun Rao
# 27                                     Azahar Shaikh
# 28                                             Manas
# 29                                             kumar
# 30                                      Sunil Vedula
# 31                                       Rajat Kumar
# 32                                   Dhruv Dev Dubey
# 33                                         Jayanth N
# 34                                            Avodha
# 35                                       Priya Khare
# 36                                       Amit Sharma
# 37                                             Kanan
# 38                              Shashikant Chaudhary
# 39                                              Brad
# 40                                      Rutuja Pawar
# 41                               Madhusudhan Sridhar
# 42                                       Ankit Sinha
# 43                                    Gaurav Chouhan
# 44                                      Rashi Kacker
# 45                                           Ashwini
# 46                                      Balaji Kolli
# 47                                    Rajani Nagaraj
# 48                                       ROHIT Kumar
# 49                                    Amir Chowdhury
# 50                                        Daniel Vaz
#
#                                Designation  \
# Sr No
# 1                               HR Manager
# 2                        Company Recruiter
# 3                               Company HR
# 4                        Company Recruiter
# 5                              Founder CEO
# 6              Recruitment Lead Consultant
# 7                        Programme Manager
# 8                         HR Administrator
# 9                                 Director
# 10                          Human Resource
# 11                            HR Team Lead
# 12                              HR Manager
# 13                        Executive Hiring
# 14                              Company HR
# 15                              Company HR
# 16                            HR Executive
# 17                              HR Manager
# 18                    Assistant Manager HR
# 19     Senior Executive Talent Acquisition
# 20                            HR Executive
# 21              Manager Talent Acquisition
# 22                                 HR Head
# 23                              HR MANAGER
# 24                            HR Recruiter
# 25                            HR Recruiter
# 26                 Manager Human Resources
# 27                       Company Recruiter
# 28                 Lead Talent acquisition
# 29                              Proprietor
# 30                                     CEO
# 31                             Founder CEO
# 32                Company Recruitment Head
# 33                         Project Manager
# 34          Business Development Associate
# 35                          Senior Manager
# 36                              Consultant
# 37            senior technology instructor
# 38                HR Recruiter/HR Excutive
# 39           Manager, Technical Recruiting
# 40                     Technical Recruiter
# 41                         Erp Implementer
# 42                          Head Analytics
# 43                 Chief Technical Officer
# 44                      Sr Product Manager
# 45                Director Global Delivery
# 46                              Co Founder
# 47                              HR Manager
# 48                               Architect
# 49                        Managing Partner
# 50                                 Partner
#
#                                               Company  \
# Sr No
# 1                                Data Science Network
# 2                       Shore Infotech India Pvt. Ltd
# 3                            MARSIAN Technologies LLP
# 4               Enerlytics Software Solutions Pvt Ltd
# 5                                     LibraryXProject
# 6          Apidel Technologies Division of Transpower
# 7                                                IFMR
# 8                         Techvantage Systems Pvt Ltd
# 9                          Weupskill- Live Wire India
# 10                   CBL Data Science Private Limited
# 11                                  SocialPrachar.com
# 12                      Infinitive Software Solutions
# 13                                 Innominds Software
# 14                                           MoneyTap
# 15                 QuantMagnum Technologies Pvt. Ltd.
# 16                                Codeachive learning
# 17                                     BISP Solutions
# 18                      BIZ INFOTECNO PRIVATE LIMITED
# 19                              Bristlecone India Ltd
# 20                                           Easi Tax
# 21                        Novelworx Digital Solutions
# 22            AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 23                      FirstTech Consaltants Pvt.Ltd
# 24                                   Affine Analytics
# 25                    Compumatrice Multimedia Pvt Ltd
# 26                                 Exela Technologies
# 27                    NEAL ANALYTICS SERVICES PVT LTD
# 28         Autumn Leaf Consulting Services Private...
# 29                                            trainin
# 30                               Nanoprecise Sci Corp
# 31                     R.S Consultancy &amp; Services
# 32                                       Confidential
# 33           Dollarbird Information Services Pvt, Ltd
# 34                                 Nikitha Palaparthi
# 35                             Independent Consultant
# 36                                    ASCO consulting
# 37                                            NY INST
# 38     3D India Staffing Research &amp; Consulting...
# 39                                        O.C. Tanner
# 40                                      Demand Matrix
# 41                                MADHUSUDHAN SRIDHAR
# 42                                     Suntech Global
# 43                           Strategic Consulting Lab
# 44                               Impel Labs Pvt. Ltd.
# 45                                       MRP Advisers
# 46                      Saras Solutions India Pvt Ltd
# 47                                        WildJasmine
# 48                                LNT Private Limited
# 49                                        Granular.ai
# 50                                       Aquis Search
#
#                                                   Skills  \
# Sr No
# 1      Classic ASP Developer, Internet Marketing Prof...
# 2      .Net, Java, Data Science, Linux Administration...
# 3      Data Science, Artificial Intelligence, Machine...
# 4      Mean Stack, javascript, angularjs, mongodb, We...
# 5      Hadoop, Spark, Digital Strategy, Data Architec...
# 6      Analytics, Business Intelligence, Business Ana...
# 7                                           Data Science
# 8      Machine Learning, algorithms, Go Getter, Compu...
# 9      Technical Training, Software Development, Pres...
# 10     Software Development, It Sales, Account Manage...
# 11     Social Media, digital media maketing, seo, smm...
# 12     Oracle Dba, Data Science, Data Warehousing, ET...
# 13     Qa, Ui/ux, Java Developer, Java Architect, C++...
# 14     Business Intelligence, Data Warehousing, Data ...
# 15     Office Administration, Hr Administration, tele...
# 16                  Data Science, Python, Data Analytics
# 17        Big Data, Hadoop, Data Analytics, Data Science
# 18     React.js, Data Science, Java, Front End, Busin...
# 19     Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 20     Telecalling, Client Interaction, Marketing, Re...
# 21                                          Data Science
# 22     Corporate Sales, Software Development, Softwar...
# 23     Data Analytics, Data Science, Machine Learning...
# 24     Data Science, Machine Learning, Python, R, Dee...
# 25     Big Data, Data Science, Artificial Intelligenc...
# 26     Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 27     Data Science, Artificial Intelligence, Machine...
# 28     Software Architecture, Vp Engineering, Product...
# 29     Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 30     Signal Processing, Machine Learning, Neural Ne...
# 31     Web Technologies, Project Management, Software...
# 32     Server Administartion, Verilog, Vhdl, Digital ...
# 33     Data Analytics, Managed Services, Team Leading...
# 34     Ethical Hacking, Security Operations Center, S...
# 35     Data Science, Artificial Intelligence, analyti...
# 36     Machine Learning, Artificial Intelligence, Dat...
# 37     C, C++, Artificial Intelligence, Python, Php, ...
# 38     Relationship Management, Retail Sales, Private...
# 39                    Data Science, Software Engineering
# 40     Data Science, Big Data Analytics, Digital Mark...
# 41                     Data Science, Recruitment, Salary
# 42     B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 43     Software Development, Business Intelligence, B...
# 44                      Data Science, Node.js, Angularjs
# 45     Data Science, Media Marketing, Resource Planni...
# 46     Data Analysis, Learning, Data Science, Compute...
# 47     Java, Hadoop, R, Machine Learning, Spark, Flum...
# 48     Software Development, Core Java, Unit Testing,...
# 49     Machine Learning, Data Science, Product Manage...
# 50     c++, Core Java, kdb, high frequency trading, h...
#
#                                                      URL
# Sr No
# 1      https://www.naukri.com/recruiters/aakashharit-...
# 2      https://www.naukri.com/recruiters/shravankumar...
# 3      https://www.naukri.com/recruiters/marsiantech?...
# 4      https://www.naukri.com/recruiters/anikagrawal-...
# 5      https://www.naukri.com/recruiters/LXP-DATASCIE...
# 6      https://www.naukri.com/recruiters/abhishekyada...
# 7      https://www.naukri.com/recruiters/menakav-3213...
# 8      https://www.naukri.com/recruiters/techvantage?...
# 9      https://www.naukri.com/recruiters/asiflucknowi...
# 10     https://www.naukri.com/recruiters/instafinanci...
# 11     https://www.naukri.com/recruiters/maheshbabuch...
# 12     https://www.naukri.com/recruiters/priyankaakir...
# 13     https://www.naukri.com/recruiters/kalpana-2078...
# 14     https://www.naukri.com/recruiters/mubarak-2905...
# 15     https://www.naukri.com/recruiters/quantmagnum?...
# 16     https://www.naukri.com/recruiters/vaishnavikud...
# 17     https://www.naukri.com/recruiters/kapildevang-...
# 18     https://www.naukri.com/recruiters/sakshichhika...
# 19     https://www.naukri.com/recruiters/ruchidhote?x...
# 20     https://www.naukri.com/recruiters/manishayadav...
# 21     https://www.naukri.com/recruiters/riyarajesh-4...
# 22     https://www.naukri.com/recruiters/rashmibhatta...
# 23     https://www.naukri.com/recruiters/faizankareem...
# 24     https://www.naukri.com/recruiters/rithikadadwa...
# 25     https://www.naukri.com/recruiters/ankitshah-21...
# 26     https://www.naukri.com/recruiters/shaunrao-302...
# 27     https://www.naukri.com/recruiters/azaharshaikh...
# 28     https://www.naukri.com/recruiters/manas-315903...
# 29     https://www.naukri.com/recruiters/kumar-337889...
# 30     https://www.naukri.com/recruiters/sunilvedula-...
# 31     https://www.naukri.com/recruiters/rajatkumar-3...
# 32     https://www.naukri.com/recruiters/dhruvdevdube...
# 33     https://www.naukri.com/recruiters/jayanthn-308...
# 34     https://www.naukri.com/recruiters/nikithapalap...
# 35     https://www.naukri.com/recruiters/priyakhare-4...
# 36     https://www.naukri.com/recruiters/amitsharma-4...
# 37     https://www.naukri.com/recruiters/deepali002g?...
# 38     https://www.naukri.com/recruiters/shashikantch...
# 39     https://www.naukri.com/recruiters/brad-4068508...
# 40     https://www.naukri.com/recruiters/rutujapawar?...
# 41     https://www.naukri.com/recruiters/madhusudhans...
# 42     https://www.naukri.com/recruiters/ankitsinha-3...
# 43     https://www.naukri.com/recruiters/gauravchouha...
# 44     https://www.naukri.com/recruiters/impel?xid=16...
# 45     https://www.naukri.com/recruiters/ashwini-3434...
# 46     https://www.naukri.com/recruiters/balajikolli-...
# 47     https://www.naukri.com/recruiters/rajaninagara...
# 48     https://www.naukri.com/recruiters/rohitkumar-3...
# 49     https://www.naukri.com/recruiters/amirchowdhur...
# 50     https://www.naukri.com/recruiters/danielvaz?xi...

# %% [markdown]
# ### Q8. Scrape the details of Highest selling novels. Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/ You have to find the following details: A) Book name B) Author name C) Volumes sold D) Publisher E) Genre

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

#open the page in automated chrome browser

driver.get("  https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/")
time.sleep(2)

# %%
# Creating Empty Lists for scrapped data

book =[]
author =[]
volumes_sold =[]
publisher =[]
genre =[]

# %%
# Scraping Book name
try:
    book_tags =driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[2]')
    for i in book_tags:
        book.append(i.text)
except NoSuchElementException:
    book.append('NA')

# %%
len(book)
# Out:
# 100

# %%
# Scraping Book author's
try:
    author_tags =driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[3]')
    for i in author_tags:
        author.append(i.text)
except NoSuchElementException:
    author.append('NA')

# %%
len(author)
# Out:
# 100

# %%
# Scraping Volumes sold
try:
    volumes_sold_tags =driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[4]')
    for i in volumes_sold_tags :
        volumes_sold.append(i.text)
except NoSuchElementException:
    volumes_sold.append('NA')

# %%
len(volumes_sold)
# Out:
# 100

# %%
# Scraping publisher
try:
    publisher_tags =driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[5]')
    for i in publisher_tags :
        publisher.append(i.text)
except NoSuchElementException:
    publisher.append('NA')

# %%
len(publisher)
# Out:
# 100

# %%
# Scraping genre
try:
    genre_tags =driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[6]')
    for i in genre_tags :
        genre.append(i.text)
except NoSuchElementException:
    genre.append('NA')

# %%
len(genre)
# Out:
# 100

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(book,author,volumes_sold,publisher,genre ))

data= pd.DataFrame(data_list, 
    columns =['Book', 'Book_ Author', 'Volumes_Sold','Publisher','Genre'],
                  index=pd.RangeIndex(start=1, stop=101, name='Rank'))

#Print the required data

print ("Details of Highest selling novels.:\n")
data
# Out:
# Details of Highest selling novels.:
#                                                    Book      Book_ Author  \
# Rank
# 1                                     Da Vinci Code,The        Brown, Dan
# 2                  Harry Potter and the Deathly Hallows     Rowling, J.K.
# 3              Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 4             Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 5                                  Fifty Shades of Grey      James, E. L.
# ...                                                 ...               ...
# 96                                            Ghost,The    Harris, Robert
# 97                       Happy Days with the Naked Chef     Oliver, Jamie
# 98                Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 99    Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 100   Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#      Volumes_Sold        Publisher                        Genre
# Rank
# 1       5,094,805       Transworld  Crime, Thriller & Adventure
# 2       4,475,152       Bloomsbury           Children's Fiction
# 3       4,200,654       Bloomsbury           Children's Fiction
# 4       4,179,479       Bloomsbury           Children's Fiction
# 5       3,758,936     Random House              Romance & Sagas
# ...           ...              ...                          ...
# 96        807,311     Random House   General & Literary Fiction
# 97        794,201          Penguin        Food & Drink: General
# 98        792,187  Scholastic Ltd.          Young Adult Fiction
# 99        791,507            Orion           Biography: General
# 100       791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# ### Q9.Scrape the details most watched tv series of all time from imdb.com. Url = https://www.imdb.com/list/ls095964455/ You have to find the following details: A) Name B) Year span C) Genre D) Run time E) Ratings F) Votes

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

#open the page in automated chrome browser

driver.get(" https://www.imdb.com/list/ls095964455/")
time.sleep(2)

# %%
# Creating Empty List for scrapped data

name =[]
year=[]
genre =[]
run_time =[]
ratings =[]
votes =[]

# %%
# Scraping Name 
try:
    name_tags =driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a")
    for i in name_tags:
        name.append(i.text)
except NoSuchElementException:
    name.append('NA')
    
# Scraping Year span
try:
    year_tags =driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/span[2]")
    for i in year_tags :
        year.append(i.text)
except NoSuchElementException:
    year.append('NA')
    
# Scraping Genre via Xpath
try:
    genre_tags =driver.find_elements(By.XPATH,"//span[@class='genre']")
    for i in genre_tags :
        genre.append(i.text)
except NoSuchElementException:
    genre.append('NA')
    
# Scraping Run Time 
try:
    run_time_tags =driver.find_elements(By.XPATH,"//span[@class='runtime']")
    for i in run_time_tags :
        run_time.append(i.text)
except NoSuchElementException:
    run_time.append('NA')
    
# Scraping Ratings
try:
    ratings_tags =driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']/span[2]")
    for i in ratings_tags :
        ratings.append(i.text)
except NoSuchElementException:
    ratings.append('NA')

# Scraping Votes
try:
    votes_tags =driver.find_elements(By.XPATH,"//span[@name='nv']")
    for i in votes_tags :
        votes.append(i.text)
except NoSuchElementException:
    votes.append('NA')

# %%
print(len(name))
print(len(genre))
print(len(year))
print(len(run_time))
print(len(ratings))
print(len(votes))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(name,year,genre,run_time,ratings,votes ))

data= pd.DataFrame(data_list, 
    columns =['Name','Year span','Genre', 'Run_Time','Ratings','Votes'],
                  index=pd.RangeIndex(start=1, stop=101, name='Rank'))

#Print the required data

print ("Details of most watched tv series of all time from imdb.com. :\n")
data
# Out:
# Details of most watched tv series of all time from imdb.com. :
#                                 Name    Year span                     Genre  \
# Rank
# 1                    Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 2                    Stranger Things     (2016– )    Drama, Fantasy, Horror
# 3                   The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 4                     13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 5                            The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ...                              ...          ...                       ...
# 96                             Reign  (2013–2017)                     Drama
# 97    A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 98                    Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 99             Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 100       The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#      Run_Time Ratings      Votes
# Rank
# 1      57 min     9.2  2,060,361
# 2      51 min     8.7  1,154,157
# 3      44 min     8.1    971,884
# 4      60 min     7.5    289,813
# 5      43 min     7.6    249,254
# ...       ...     ...        ...
# 96     42 min     7.4     49,680
# 97     50 min     7.8     60,726
# 98     42 min     8.1    195,452
# 99     45 min     7.1     41,136
# 100   572 min     8.6    237,993
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Q10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

#open the page in automated chrome browser

driver.get(" https://archive.ics.uci.edu/ ")
time.sleep(2)

# %%
# Clicking on all datasets links
dataset=driver.find_element(By.XPATH,"//a[@href='datasets.php']")
dataset.click()
time.sleep(1)

# %%
# Creating empty lists for scrapped data

name =[]
dtype =[]
task =[]
attribute_type =[]
no_of_instances =[]
no_of_Attri=[]
year=[]

# %%
# Scraping DataSet Name

try:
    name_tags =driver.find_elements(By.XPATH,"//p[@class='normal']/b/a")
    for i in name_tags:
        name.append(i.text)
except NoSuchElementException:
    name.append('NA')

# %%
# Scraping Data Type
try:
    dtype_tags=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]')
    for i in dtype_tags[1:]:
        dtype.append(i.text)
except NoSuchElementException:
    dtype.append('NA')
    
# Scraping Task
try:
    task_tags =driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]')
    for i in task_tags [1:]:
        task.append(i.text)
except NoSuchElementException:
    task.append('NA')
    
# Scraping Attribute_Type
try:
    attribute_type_tags =driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]')
    for i in attribute_type_tags[1:]:
        attribute_type.append(i.text)
except NoSuchElementException:
    attribute_type.append('NA')
    
# Scraping No_of_Instances
try:
    no_of_instances_tags =driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]')
    for i in no_of_instances_tags [1:]:
        no_of_instances.append(i.text)
except NoSuchElementException:
    no_of_instances.append('NA')

# Scraping No_of_Attribute
try:
    no_of_Attri_tags =driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]')
    for i in no_of_Attri_tags [1:]:
        no_of_Attri.append(i.text)
except NoSuchElementException:
    no_of_Attri.append('NA')
    
# Scraping Year
try:
    year_tags =driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]')
    for i in year_tags[1:]:
        year.append(i.text)
except NoSuchElementException:
    year.append('NA')

# %%
print(len(name))
print(len(dtype))
print(len(task))
print(len(attribute_type))
print(len(no_of_instances))
print(len(no_of_Attri))
print(len(year))
# Out:
# 622
# 622
# 622
# 622
# 622
# 622
# 622

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(name,dtype,task,attribute_type,no_of_instances,no_of_Attri,year))

data= pd.DataFrame(data_list, 
    columns =['Name','Data Type','Task', 'Attribute_Type','No_of_Instances','No_of_Attribute','Year'],
                  index=pd.RangeIndex(start=1, stop=623, name='Sr No'))

#Print the required data

print ("Details of Datasets from UCI machine learning repositories :\n")
data
# Out:
# Details of Datasets from UCI machine learning repositories :
#                                                     Name  \
# Sr No
# 1                                                Abalone
# 2                                                  Adult
# 3                                              Annealing
# 4                           Anonymous Microsoft Web Data
# 5                                             Arrhythmia
# ...                                                  ...
# 618    Influenza outbreak event prediction via Twitte...
# 619                        Turkish Music Emotion Dataset
# 620                        Maternal Health Risk Data Set
# 621                            Room Occupancy Estimation
# 622    Image Recognition Task Execution Times in Mobi...
#
#                         Data Type                  Task  \
# Sr No
# 1                   Multivariate        Classification
# 2                   Multivariate        Classification
# 3                   Multivariate        Classification
# 4                                  Recommender-Systems
# 5                   Multivariate        Classification
# ...                           ...                   ...
# 618                 Multivariate        Classification
# 619                 Multivariate        Classification
# 620                                     Classification
# 621    Multivariate, Time-Series        Classification
# 622                   Univariate            Regression
#
#                     Attribute_Type No_of_Instances No_of_Attribute   Year
# Sr No
# 1      Categorical, Integer, Real            4177               8   1995
# 2            Categorical, Integer           48842              14   1996
# 3      Categorical, Integer, Real             798              38
# 4                     Categorical           37711             294   1998
# 5      Categorical, Integer, Real             452             279   1998
# ...                            ...             ...             ...    ...
# 618                 Integer, Real           75840             525   2020
# 619                 Integer, Real             400              50   2020
# 620                                          1014               7   2020
# 621                          Real           10129              16   2021
# 622                          Real            4000               2   2021
#
# [622 rows x 7 columns]
