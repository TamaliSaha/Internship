# %% [markdown]
# # Web Scraping Assignment :3
#
# ## Flip Robo Technologies | Internship: 31
#
# ### Submitted By : Tamali Saha (tamali428@gmail.com)

# %%
#import necessary librabies for webscraping with selenium

import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time
import requests
from time import sleep

# %% [markdown]
# ### Q1:  Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

#open the page in automated chrome browser

driver.get("https://www.amazon.in/")
time.sleep(2)

# %%
# Taking input from user

user_input=input('Enter the Product you which you want to search :')
# Out:
# Enter the Product you which you want to search :guitar

# %%
# Finding search

search=driver.find_element(By.XPATH,'//input[@id="twotabsearchtextbox"]')

# clearing any previous input in search bar

search.clear()

# %%
# Puting input to search button and click on seach

search.send_keys(user_input)

button=driver.find_element(By.XPATH,'//input[@id="nav-search-submit-button"]')
button.click()

# %% [markdown]
# ### Q2: In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
# Make Empty list to save the scrapped data

brand_name =[]
product = []
price =[]
exchange =[]
excepted_delivery =[]
availability =[]
url =[]

# %% [markdown]
# #### First scrape URL of the searched product for first 3 pages

# %%
start= 0
end= 3
for page in range(start, end):
    url_tags =driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url_tags:
        url.append(i.get_attribute('href'))
    time.sleep(2)
    
    # locating next page button and clicking
    
    next_page = driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    next_page.click()
    time.sleep(6)

# %%
len(url)
# Out:
# 162

# %%
for i in url:
    driver.get(i)
    time.sleep(3)
    
    # Extracting Brand Name
    try:
        brand_tags =driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[4]/div[4]/div[43]/div/table/tbody/tr[1]/td[2]/span')
        brand_name.append(brand_tags.text) 
        
    except NoSuchElementException:
        brand_name.append('-')
    time.sleep(2)
    
    # Extracting product name
    try:
        product_tags =driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[4]/div[4]/div[1]/div/h1/span')
        product.append(product_tags.text)
        
    except NoSuchElementException:
        product.append('-')
    time.sleep(2)
    
    # Extracting Price
    try:
        price_tags =driver.find_element(By.XPATH,'//span[@class="a-price a-text-price a-size-medium apexPriceToPay"]')
        price.append(price_tags.text)
        
    except NoSuchElementException:
        price.append('-')
    time.sleep(2)
    
    # Extracting Return or exchange details
    try:
        ex_tags =driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[4]/div[4]/div[22]/div[2]/div/div/div/div[2]/span/div[2]/a')
        exchange.append(ex_tags.text)
        
    except NoSuchElementException:
        exchange.append('-')
    time.sleep(2)
    
    # Extracting Expected Delivery via Xpath
    try:
        delivery_tags =driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[4]/div[1]/div[3]/div/div/div/div/form/div/div/div/div/div[3]/div/div[2]/div[8]/div[1]/div/div/div[2]/span/span[1]')
        excepted_delivery.append(delivery_tags.text)
        
    except NoSuchElementException:
        excepted_delivery.append('-')
    time.sleep(2)
    
    # Extracting availability via Xpath
    try:
        availability_tags =driver.find_element(By.XPATH,'//span[@class="a-size-medium a-color-success"]')
        availability.append(availability_tags.text)
        
    except NoSuchElementException:
        availability.append('-')
    time.sleep(2)

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(brand_name,product,price, exchange,excepted_delivery,availability, url))

data= pd.DataFrame(data_list, 
    columns =['Brand_Name', 'Product', 'Price', 'Return/Exchange','Excepted Delivery','Availability','URL'],
    index=pd.RangeIndex(start=1, stop=163, name='Sr. No.'))

#Print the required data

print ("Details of each product listed in first 3 pages from amazon.com:\n")
data
# Out:
# Details of each product listed in first 3 pages from amazon.com:
#           Brand_Name                                            Product  \
# Sr. No.
# 1            Kadence  Kadence Frontier guitar with Online Guitar lea...
# 2                  -                                                  -
# 3        Gamma Audio  Gamma Audio Basswood Acoustic Guitar Kit With ...
# 4              VAULT  Vault EA40 41 inch Premium Solid Spruce-Top Cu...
# 5                  -                                                  -
# ...              ...                                                ...
# 158        Blueberry  Blueberry 38C, 38" Acoustic Guitar Kit with Ba...
# 159                -                                                  -
# 160       Guitar Bro  GUITAR BRO - COMBO (Black Acoustic Guitar for ...
# 161                -                                                  -
# 162                -                                                  -
#
#           Price Return/Exchange         Excepted Delivery  \
# Sr. No.
# 1        ₹3,999               -                         -
# 2        ₹8,999               -                         -
# 3             -               -        Tuesday, 4 October
# 4        ₹7,077               -        Tuesday, 4 October
# 5        ₹1,774               -                         -
# ...         ...             ...                       ...
# 158      ₹2,426               -         Monday, 3 October
# 159           -               -                         -
# 160           -               -  September 30 - October 3
# 161           -               -                         -
# 162           -               -                         -
#
#                   Availability  \
# Sr. No.
# 1
# 2                    In stock.
# 3        Only 1 left in stock.
# 4                    In stock.
# 5                    In stock.
# ...                        ...
# 158                  In stock.
# 159                  In stock.
# 160                  In stock.
# 161                  In stock.
# 162                  In stock.
#
#                                                        URL
# Sr. No.
# 1        https://www.amazon.in/gp/slredirect/picassoRed...
# 2        https://www.amazon.in/gp/slredirect/picassoRed...
# 3        https://www.amazon.in/gp/slredirect/picassoRed...
# 4        https://www.amazon.in/gp/slredirect/picassoRed...
# 5        https://www.amazon.in/Juarez-Acoustic-Cutaway-...
# ...                                                    ...
# 158      https://www.amazon.in/Blueberry-Acoustic-Guita...
# 159      https://www.amazon.in/JUAREZ-Arp%C3%A9ggio-Aco...
# 160      https://www.amazon.in/GUITAR-BRO-Acoustic-Begi...
# 161      https://www.amazon.in/Jackson-JS-Dinky-JS11-El...
# 162      https://www.amazon.in/Blueberry-38C-Acoustic-G...
#
# [162 rows x 7 columns]

# %% [markdown]
# ### Q3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

#open the page in automated chrome browser

driver.get("https://images.google.com/")
time.sleep(5)

# %% [markdown]
# #### Scraping for fruits:

# %%
# Finding search

search=driver.find_element(By.XPATH,'//input[@class="gLFyf gsfi"]')

# clearing any previous input in search bar

search.clear()

# Puting 'fruits' to search button and click on seach

search.send_keys('fruits')
button=driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
button.click()

# %%
# Scrolling window using ScrollBy

driver.execute_script("window.scrollBy(0,10000)","")

# %%
image_tag= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

url=[]
for img in image_tag:
    x= img.get_attribute('src')
    if x is not None:
        if(x[0:4] == 'http'):
            url.append(x)

# %%
len(url)
# Out:
# 45

# %%
for i in range(len(url)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(url[i])
    file = open(r"E:\FlipRobo\Webscraping3\Fruits" +str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images

# %% [markdown]
# #### Scraping for cars:

# %%
# Finding search

search=driver.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/div/div[2]/input')

# clearing any previous input in search bar

search.clear()

# Puting 'cars' to search button and click on seach

search.send_keys('cars')
button=driver.find_element(By.XPATH,'//span[@class="n6h3Rc"]')
button.click()

# %%
# Scrolling window using ScrollBy

driver.execute_script("window.scrollBy(0,10000)","")

# %%
image_tag= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

url=[]
for img in image_tag:
    x= img.get_attribute('src')
    if x is not None:
        if(x[0:4] == 'http'):
            url.append(x)

# %%
len(url)
# Out:
# 49

# %%
for i in range(len(url)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(url[i])
    file = open(r"E:\FlipRobo\Webscraping3\Cars" +str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images

# %% [markdown]
# #### Scraping for Machine Learning:

# %%
# Finding search

search=driver.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/div/div[2]/input')

# clearing any previous input in search bar

search.clear()

# Puting 'Machine Learning' to search button and click on seach

search.send_keys('Machine Learning')
button=driver.find_element(By.XPATH,'//span[@class="n6h3Rc"]')
button.click()

# %%
# Scrolling window using ScrollBy

driver.execute_script("window.scrollBy(0,10000)","")

# %%
image_tag= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

url=[]
for img in image_tag:
    x= img.get_attribute('src')
    if x is not None:
        if(x[0:4] == 'http'):
            url.append(x)

# %%
len(url)
# Out:
# 54

# %%
for i in range(len(url)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(url[i])
    file = open(r"E:\FlipRobo\Webscraping3\Machine_Learning" +str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images

# %% [markdown]
# ### Q4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"chromedriver.exe")

#open the page in automated chrome browser

driver.get('http://www.flipkart.com/')
time.sleep(1)

# %%
#close popup window

try:
    popup = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _2doB4z"]')
    popup.click()
except NoSuchElementException:
    print('Popup Window is not present')

# %%
# Finding Search bar

search=driver.find_element(By.XPATH,'//input[@class="_3704LK"]')

# Clearing any previous input in search bar

search.clear()

# Putting 'Oneplus Nord' to search button and click on seach

search.send_keys('Oneplus Nord')
button=driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')
button.click()

# %%
# Making empty list to scrape data
brand =[]
smartphone =[]
colour =[]
ram=[]
rom =[]
primary_camera=[]
dual_camera=[]
display_size=[]
battery_capacity=[]
price =[]
url=[]

# %%
url_tags =driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for i in url_tags:
    x=i.get_attribute('href')
    url.append(x)

# %%
len(url)
# Out:
# 24

# %%
for i in url:
    driver.get(i)
    time.sleep(1)
    
    # Expanding specification table by clicking on read more button
    try:
        Read_more=driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]')
        Read_more.click()
        
    except NoSuchElementException:
        print('NoSuchElementException Occur')
        pass
    
    # Extracting Brand Name
    try:
        brand_tags=driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')
        brand.append(brand_tags.text.split()[0])
    
    except NoSuchElementException:
        brand.append('-')
        
    # Extracting smartphone Name
    try:
        smartphone_tags=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')
        smartphone.append(smartphone_tags.text)
    
    except NoSuchElementException:
        smartphone.append('-')
        
    # Extracting Colour
    try:
        colour_tag =driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')
        colour.append(colour_tag.text)
    
    except NoSuchElementException:
        colour.append('-')
        
    # Extracting Storage ram
    try:
        ram_tag =driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr[2]/td[2]/ul/li')
        ram.append(ram_tag.text)
        
    except NoSuchElementException:
        ram.append('-')
    
        
    # Extracting Storage rom
    try:
        rom_tag =driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr[1]/td[2]/ul/li')
        rom.append(rom_tag.text)
        
    except NoSuchElementException:
        rom.append('-')
        
    # Extracting Primary camera details
    p=[]
    try:
        camera_tags=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[1]/td[2]/ul/li')
        p.append(camera_tags.text)
        for i in p:
            if i=='Yes':
                primary_camera.append('--')
            else:
                primary_camera.append(i)
                
    except NoSuchElementException:
        primary_camera.append('-')
                
        
    # Extracting Dual camera lens details
    try:
        dual_camera_tags=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[2]/td[2]/ul/li')
        dual_camera.append(dual_camera_tags.text)
    
    except NoSuchElementException:
        dual_camera.append('-')
     
     
    # Extracting Display size details
    try:
        display_size_tags=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/table/tbody/tr[1]/td[2]/ul/li')
        display_size.append(display_size_tags.text)
    
    except NoSuchElementException:
        display_size.append('-')
      
      
    # Extracting battery capacity details
    l=[]
    try:
        battery_capacity_tags=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][7]/table/tbody/tr/td[2]/ul/li')
        l.append(battery_capacity_tags.text)
        for i in l:
            if len(i)== 8:
                battery_capacity.append(i)
            else:
                battery_capacity.append("--")
    
    except NoSuchElementException:
        battery_capacity.append('-')
        
        
    # Extracting price details
    try:
        price_tags=driver.find_element(By.XPATH,'//div[@class="_30jeq3 _16Jk6d"]')
        price.append(price_tags.text)
    
    except NoSuchElementException:
        price.append('-')

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(brand,smartphone,colour, ram,rom,primary_camera,dual_camera,display_size,battery_capacity,price,url))

data= pd.DataFrame (data_list,
    columns =['Brand_Name', 'Smartphone Name', 'Colour', 'RAM','Storage(ROM)', 'Primary Camera','Dual Camera',
              'Display Size', 'Battery Capacity','Price', 'URL'],
    index = pd.RangeIndex(start=1, stop=25, name='Sr. No.'))

#Print the required data

data.to_csv("oneplus_details.csv", index= False)

print("Details of each product listed in first page from flipkart.com:\n")
data
# Out:
# Details of each product listed in first page from flipkart.com:
#         Brand_Name    Smartphone Name        Colour    RAM Storage(ROM)  \
# Sr. No.
# 1          OnePlus  Nord CE 2 Lite 5G    Black Dusk   6 GB       128 GB
# 2          OnePlus         Nord 2T 5G      Jade Fog   8 GB       128 GB
# 3          OnePlus         Nord 2T 5G      Jade Fog   8 GB       128 GB
# 4          OnePlus         Nord CE 5G  Charcoal Ink   8 GB       128 GB
# 5          OnePlus               Nord     Gray Onyx  12 GB       256 GB
# 6          OnePlus               Nord     Gray Onyx   6 GB        64 GB
# 7          OnePlus               Nord   Blue Marble  12 GB       256 GB
# 8          OnePlus               Nord     Gray Onyx   8 GB       128 GB
# 9          OnePlus               Nord   Blue Marble   8 GB       128 GB
# 10         OnePlus               Nord   Blue Marble   6 GB        64 GB
# 11         OnePlus  Nord CE 2 Lite 5G     Blue Tide   6 GB       128 GB
# 12         OnePlus  Nord CE 2 Lite 5G     Blue Tide   6 GB       128 GB
# 13         OnePlus   Nord CE2 Lite 5G     Blue Tide   8 GB       128 GB
# 14         OnePlus  Nord CE 2 Lite 5G     Blue Tide   6 GB       128 GB
# 15         OnePlus  Nord CE 2 Lite 5G    Black Dusk   6 GB       128 GB
# 16         OnePlus  Nord CE 2 Lite 5G    Black Dusk   8 GB       128 GB
# 17         OnePlus  Nord CE 2 Lite 5G    Black Dusk   6 GB       128 GB
# 18         OnePlus         Nord 2T 5G   Gray Shadow  12 GB       256 GB
# 19         OnePlus       Nord CE 2 5G   Gray Mirror   6 GB       128 GB
# 20         OnePlus       Nord CE 2 5G   Bahama Blue   8 GB       128 GB
# 21         OnePlus         Nord 2T 5G      Jade Fog  12 GB       256 GB
# 22         OnePlus         Nord 2T 5G      Jade Fog  12 GB       256 GB
# 23         OnePlus         Nord 2T 5G      Jade Fog  12 GB       256 GB
# 24         OnePlus          Nord 2 5G   Gray Sierra  12 GB       256 GB
#
#            Primary Camera                 Dual Camera          Display Size  \
# Sr. No.
# 1        64MP Rear Camera  Primary & Secondary Camera  16.74 cm (6.59 inch)
# 2        50MP Rear Camera  Primary & Secondary Camera   17.02 cm (6.7 inch)
# 3        50MP Rear Camera              Primary Camera   17.02 cm (6.7 inch)
# 4        64MP Rear Camera              Primary Camera  16.33 cm (6.43 inch)
# 5                     Yes                  48MP + 8MP  16.36 cm (6.44 inch)
# 6                     Yes                  48MP + 8MP  16.36 cm (6.44 inch)
# 7                     Yes                  48MP + 8MP  16.36 cm (6.44 inch)
# 8                     Yes                  48MP + 8MP  16.36 cm (6.44 inch)
# 9                     Yes                  48MP + 8MP  16.36 cm (6.44 inch)
# 10                    Yes                  48MP + 8MP  16.36 cm (6.44 inch)
# 11                    Yes            64MP Rear Camera  16.74 cm (6.59 inch)
# 12       64MP Rear Camera  Primary & Secondary Camera  16.74 cm (6.59 inch)
# 13       64MP Rear Camera  Primary & Secondary Camera  16.74 cm (6.59 inch)
# 14       64MP Rear Camera  Primary & Secondary Camera  16.74 cm (6.59 inch)
# 15       64MP Rear Camera  Primary & Secondary Camera  16.74 cm (6.59 inch)
# 16       64MP Rear Camera  Primary & Secondary Camera  16.74 cm (6.59 inch)
# 17       64MP Rear Camera              Primary Camera  16.74 cm (6.59 inch)
# 18       50MP Rear Camera              Primary Camera   17.02 cm (6.7 inch)
# 19       64MP Rear Camera              Primary Camera  16.33 cm (6.43 inch)
# 20       64MP Rear Camera  Primary & Secondary Camera  16.33 cm (6.43 inch)
# 21       50MP Rear Camera              Primary Camera   17.02 cm (6.7 inch)
# 22       50MP Rear Camera  Primary & Secondary Camera   17.02 cm (6.7 inch)
# 23       50MP Rear Camera  Primary & Secondary Camera   17.02 cm (6.7 inch)
# 24       50MP Rear Camera              Primary Camera  16.33 cm (6.43 inch)
#
#         Battery Capacity    Price  \
# Sr. No.
# 1               5000 mAh  ₹19,999
# 2               4500 mAh  ₹28,989
# 3               4500 mAh  ₹28,940
# 4               4500 mAh  ₹24,990
# 5                     --  ₹29,999
# 6                     --  ₹24,999
# 7                     --  ₹29,999
# 8                     --  ₹27,999
# 9                     --  ₹27,999
# 10                    --  ₹24,999
# 11                    --  ₹19,400
# 12              5000 mAh  ₹19,890
# 13              5000 mAh  ₹21,899
# 14              5000 mAh  ₹18,999
# 15              5000 mAh  ₹19,850
# 16              5000 mAh  ₹21,899
# 17              5000 mAh  ₹19,680
# 18              4500 mAh  ₹31,999
# 19              4500 mAh  ₹23,990
# 20              4500 mAh  ₹24,797
# 21              4500 mAh  ₹31,999
# 22              4500 mAh  ₹33,990
# 23              4500 mAh  ₹33,999
# 24              4500 mAh  ₹34,990
#
#                                                        URL
# Sr. No.
# 1        https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 2        https://www.flipkart.com/oneplus-nord-2t-5g-ja...
# 3        https://www.flipkart.com/oneplus-nord-2t-5g-ja...
# 4        https://www.flipkart.com/oneplus-nord-ce-5g-ch...
# 5        https://www.flipkart.com/oneplus-nord-gray-ony...
# 6        https://www.flipkart.com/oneplus-nord-gray-ony...
# 7        https://www.flipkart.com/oneplus-nord-blue-mar...
# 8        https://www.flipkart.com/oneplus-nord-gray-ony...
# 9        https://www.flipkart.com/oneplus-nord-blue-mar...
# 10       https://www.flipkart.com/oneplus-nord-blue-mar...
# 11       https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 12       https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 13       https://www.flipkart.com/oneplus-nord-ce2-lite...
# 14       https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 15       https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 16       https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 17       https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 18       https://www.flipkart.com/oneplus-nord-2t-5g-gr...
# 19       https://www.flipkart.com/oneplus-nord-ce-2-5g-...
# 20       https://www.flipkart.com/oneplus-nord-ce-2-5g-...
# 21       https://www.flipkart.com/oneplus-nord-2t-5g-ja...
# 22       https://www.flipkart.com/oneplus-nord-2t-5g-ja...
# 23       https://www.flipkart.com/oneplus-nord-2t-5g-ja...
# 24       https://www.flipkart.com/oneplus-nord-2-5g-gra...

# %% [markdown]
# ### Q5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"chromedriver.exe")

#open the page in automated chrome browser

driver.get('https://www.google.co.in/maps')
time.sleep(1)

# %%
# Finding Search bar

search=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/form/div[2]/div[3]/div/input[1]')

# Clearing any previous input in search bar

search.clear()

# Putting 'Kolkata' to search button and click on seach

search.send_keys('Kolkata')
button=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/div[1]/button')
button.click()

# %%
# finding the current url

current_URL=driver.current_url

print('Current url for given location is :',current_URL)
# Out:
# Current url for given location is : https://www.google.co.in/maps/place/Kolkata,+West+Bengal/@22.6757521,88.049525,10z/data=!3m1!4b1!4m5!3m4!1s0x39f882db4908f667:0x43e330e68f6c2cbc!8m2!3d22.572646!4d88.363895

# %%
# finding total location from URL

if "@" in current_URL:
        loc = current_URL.split('@')[1].split(',*/data')[0].split(',')
loc
# Out:
# ['22.6757521',
#  '88.049525',
#  '10z/data=!3m1!4b1!4m5!3m4!1s0x39f882db4908f667:0x43e330e68f6c2cbc!8m2!3d22.572646!4d88.363895']

# %%
# scraping latitude and longitude from URL

try:
    if "@" in current_URL:
        loc = current_URL.split('@')[1].split(',*/data')[0].split(',')
        print('Latitude of given Location:',loc[0])
        print('Longitude of given Location:',loc[1])
except:
    print('Location details is not found in URL')
# Out:
# Latitude of given Location: 22.6757521
# Longitude of given Location: 88.049525

# %% [markdown]
# ### Q6. Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 –September 20) from trak.in.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"chromedriver.exe")

#open the page in automated chrome browser

driver.get('https://www.trak.in')
time.sleep(1)

# %%
# Clicking 'funding deals'

funding_deals_tags = driver.find_element(By.XPATH,'//li[@id="menu-item-51510"]/a')
x= funding_deals_tags.get_attribute('href')
driver.get(x)

# %%
# Making Empty list
date=[]
startup=[]
industry=[]
sub_vertical=[]
city=[]
investor=[]
investment_type=[]
amount=[]

# %% [markdown]
# For quarter July 20 - September 20, the range numbers are between 48-51. et's trake it and scrape the data.

# %%
for i in range(48,51):
    
    # Extracting Date
    try:
        date_tags =driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
        for i in date_tags:
            date.append(i.text)
    except:
        date.append('--')

# %%
for i in range(48,51):
        
    # Extracting startup name
    try:
        startup_tags =driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
        for i in startup_tags:
            startup.append(i.text)
    except:
        startup.append('--')

# %%
for i in range(48,51):

    # Extracting Industry
    try:
        industry_tags= driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
        for i in industry_tags:
            industry.append(i.text)
    except:
        industry.append('--')

# %%
for i in range(48,51):

    # Extracting subvertical
    try:
        subvertical_tags =driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
        for i in subvertical_tags:
            sub_vertical.append(i.text)
    except:
        sub_vertical.append('--')

# %%
for i in range(48,51):

    # Extracting city/location
    try:
        city_tags =driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
        for i in city_tags:
            city.append(i.text)
    except:
        city.append('--')

# %%
for i in range(48,51):

    # Extracting Investor
    try:
        investor_tags =driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
        for i in investor_tags:
            investor.append(i.text)
    except:
        investor.append('--')

# %%
for i in range(48,51):   
    
    # Extracting Investment type
    try:
        investment_tags=driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
        for i in investment_tags:
            investment_type.append(i.text)
    except:
        investment_type.append('--')

# %%
for i in range(48,51): 
    
    # Extracting Amount
    try:
        amount_tags =driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
        for i in amount_tags:
            amount.append(i.text)
    except:
        amount.append('--')

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(date,startup,industry,sub_vertical,city,investor,investment_type,amount))

data= pd.DataFrame (data_list,
    columns =['Date(dd/mm/yyyy)', 'Startup Name', 'Industry/Vertical', 'Sub-Vertical','City/Location','Investor Name',
              'Investment Type', 'Amount(In USD)'])

#Print the required data

data.to_csv("oneplus_details.csv", index= True)

print("Details of all the funding deals for second quarter (i.e. July 20 –September 20) from trak.in:\n")
data
# Out:
# Details of all the funding deals for second quarter (i.e. July 20 –September 20) from trak.in:
#    Date(dd/mm/yyyy)               Startup Name  \
# 0        15/07/2020                   Flipkart
# 1        16/07/2020                    Vedantu
# 2        16/07/2020                       Crio
# 3        14/07/2020                    goDutch
# 4        13/07/2020                   Mystifly
# 5        09/07/2020               JetSynthesys
# 6        10/07/2020                   gigIndia
# 7        15/07/2020                  PumPumPum
# 8        14/07/2020                       FLYX
# 9        13/07/2020  Open Appliances Pvt. Ltd.
# 10       15/08/2020                     Practo
# 11       13/08/2020                    Medlife
# 12       13/08/2020                  HungerBox
# 13       04/08/2020                      Dunzo
# 14       11/08/2020                   Terra.do
# 15       12/08/2020                  Classplus
# 16       14/08/2020                       Niyo
# 17       10/08/2020                  ZestMoney
# 18       07/08/2020                FreshToHome
# 19       13/08/2020                    Eduvanz
# 20       08/09/2020                     Byju’s
# 21       12/09/2020                  mCaffeine
# 22       09/09/2020                     Qshala
# 23       02/09/2020                      Winzo
# 24       09/09/2020                Hippo Video
# 25       07/09/2020                    Melorra
# 26       07/09/2020                        1mg
# 27       31/08/2020                      mfine
# 28       31/08/2020                       Apna
# 29       03/09/2020                    Railofy
#
#                          Industry/Vertical  \
# 0                               E-commerce
# 1                                  EduTech
# 2                                  EduTech
# 3                                  FinTech
# 4                      Airfare Marketplace
# 5                 Gaming and Entertainment
# 6                              Marketplace
# 7                        Automotive Rental
# 8                               OTT Player
# 9                   Information Technology
# 10                              HealthTech
# 11                              E-commerce
# 12                                FoodTech
# 13                   Hyper-local Logistics
# 14                                 EduTech
# 15                                 EduTech
# 16                                 FinTech
# 17                                 FinTech
# 18                              E-commerce
# 19                                 FinTech
# 20                                 EduTech
# 21                           Personal Care
# 22                                 EduTech
# 23                           Online Gaming
# 24  Video Customer Experience(CX) Platform
# 25                              E-commerce
# 26                              E-commerce
# 27                              HealthTech
# 28                         Human Resources
# 29                          Transportation
#
#                                          Sub-Vertical  \
# 0                                          E-commerce
# 1                                     Online Tutoring
# 2                    Learning Platform for Developers
# 3                                      Group Payments
# 4   Ticketing, Airline Retailing, and Post-Ticketi...
# 5                            Gaming and Entertainment
# 6                           Crowd Sourcing, Freelance
# 7                           Used Car-leasing platform
# 8                            Streaming Social Network
# 9               Internet-of-Things Security Solutions
# 10                           Health care and Wellness
# 11                                    Online Pharmacy
# 12                       Online Food Delivery Service
# 13                           Online Delivery Services
# 14                  Online Climate School, E-learning
# 15                        E-learning, Online Tutoring
# 16                                 Financial Services
# 17                                 Financial Services
# 18                                      Food Delivery
# 19                                 Financial Services
# 20                                    Online Tutoring
# 21                                Skincare & Haircare
# 22                 Online Curiosity Platform for Kids
# 23                                      Online Gaming
# 24             Video Customer Experience(CX) Platform
# 25                               Online Jewelry Store
# 26                                    Online Pharmacy
# 27                      On-Demand Healthcare Services
# 28                               Recruitment Platform
# 29                       WL & RAC protection platform
#
#                                  City/Location  \
# 0                                    Bangalore
# 1                                    Bangalore
# 2                                    Bangalore
# 3                                       Mumbai
# 4                      Singapore and Bangalore
# 5                                         Pune
# 6                                         Pune
# 7                                      Gurgaon
# 8                           New York and Delhi
# 9                                    Bangalore
# 10                                   Bangalore
# 11                                   Bangalore
# 12                                   Bangalore
# 13                                   Bangalore
# 14                       Stanford, California,
# 15                                       Noida
# 16                                   Bangalore
# 17                                   Bangalore
# 18                                   Bangalore
# 19                                      Mumbai
# 20                                   Bangalore
# 21                                      Mumbai
# 22                                   Bangalore
# 23                                   New Delhi
# 24  Newark, Delaware, United States of Amercia
# 25                                   Bangalore
# 26                                     Gurgaon
# 27                                   Bangalore
# 28                                   Bangalore
# 29                                      Mumbai
#
#                                         Investor Name         Investment Type  \
# 0                                         Walmart Inc                     M&A
# 1                                   Coatue Management                Series D
# 2                                         021 Capital            pre-Series A
# 3   Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 4                                    Recruit Co. Ltd.            pre-Series B
# 5            Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 6        Incubate Fund India and Beyond Next Ventures            pre-Series A
# 7                            Early Adapters Syndicate                    Seed
# 8               Raj Mishra, founder of AIT Global Inc                pre-Seed
# 9                              Unicorn India Ventures  Venture-Series Unknown
# 10                                        A1A Company                Series F
# 11         Prasid Uno Family Trust and SC Credit Fund
# 12  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 13                                   Existing Backers             In Progress
# 14  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 15                                        Falcon Edge             In Progress
# 16                                Niyo Solutions Inc.
# 17                            Primrose Hills Ventures
# 18                                     Ascent Capital                 Venture
# 19                              Sequoia India, Unitus                Series A
# 20  Silver Lake, Tiger Global, General Atlantic an...          Private Equity
# 21  Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 22                                 Rainmatter Capital                   Angel
# 23  Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 24  Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 25                         Shadow Holdings, Lightbox.          Debt Financing
# 26         Gaja Capital, Tata Capital, Partners Group             In Progress
# 27                                   Caretech Pte Inc                Series B
# 28         Lightspeed India and Sequoia Capital India                Series A
# 29                                  Chiratae Ventures                    Seed
#
#      Amount(In USD)
# 0     1,200,000,000
# 1       100,000,000
# 2           934,160
# 3         1,700,000
# 4         3,300,000
# 5           400,000
# 6           974,200
# 7           292,800
# 8           200,000
# 9           500,000
# 10       32,000,000
# 11       23,000,000
# 12        1,560,000
# 13       30,000,000
# 14        1,400,000
# 15  upto 15,000,000
# 16        6,000,000
# 17       10,670,000
# 18       16,200,000
# 19        5,000,000
# 20      500,000,000
# 21        3,000,000
# 22          370,000
# 23       15,500,000
# 24        4,500,000
# 25   upto 8,900,000
# 26      100,000,000
# 27        5,400,000
# 28        8,000,000
# 29          950,000

# %% [markdown]
# ### Q7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"chromedriver.exe")

#open the page in automated chrome browser

driver.get('https://www.digit.in')
time.sleep(2)

# %%
# Clicking on top 10 option button in menu bar

top10= driver.find_element(By.XPATH,'//div[@class="menu"]/ul/li[4]/a')
top10.click()
time.sleep(2)

# Clicking on Laptop
lap= driver.find_element(By.XPATH,'//div[@class="categoty_list"]/button[2]')
lap.click()

# Clicking on Best gaming laptops

gaming_lap =driver.find_element(By.XPATH,'//div[@id="laptops"]/div[3]/a').get_attribute('href')
driver.get(gaming_lap)
time.sleep(3)

# %%
# Making Empty list for scraping data

laptop_model =[]
processor =[]
display = []
OS =[]
memory =[]
graphics_processor =[]
dimension =[]
weight =[]
url=[]

# %%
# Extracting Laptop model

laptop_tags =driver.find_elements(By.XPATH, '//div[@class="left_side"]/a/h3')
for i in laptop_tags:
    laptop_model.append(i.text)

# Extracting processor

processor_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[3]/td[3]')
for i in processor_tags:
    processor.append(i.text)
    
# Extracting display

display_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[4]/td[3]')
for i in display_tags:
    display.append(i.text)

# Extracting OS

OS_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[5]/td[3]')
for i in OS_tags:
    OS.append(i.text)    

# Extracting memory

memory_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[6]/td[3]')
for i in memory_tags:
    memory.append(i.text)
    
# Extracting graphics_processor

graphics_processor_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[7]/td[3]')
for i in graphics_processor_tags:
    graphics_processor.append(i.text)
    
# Extracting dimension

dimension_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]')
for i in dimension_tags:
    dimension.append(i.text.split("&")[0])
    
# Extracting weight

weight_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]')
for i in weight_tags:
    weight.append(i.text.split("&")[1])
    
# Extracting url details

url_tags =driver.find_elements(By.XPATH,'//div[@class="left_side"]/a')
for i in url_tags:
    url.append(i.get_attribute("href"))

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(laptop_model,processor,display,OS,memory,graphics_processor,dimension,weight,url))

data= pd.DataFrame (data_list,
    columns =['Laptop Model', 'Processor', 'Display', 'OS','Memory','Graphics Processor',
              'Dimension', 'Weight', 'URL'], index= pd.RangeIndex(start=1, stop=11, name='Sr. No.'))

#Print the required data

data.to_csv("Digit_laptop_details.csv", index= False)

print("Details of all the available details of best gaming laptops from digit.in:\n")
data
# Out:
# Details of all the available details of best gaming laptops from digit.in:
#                                           Laptop Model  \
# Sr. No.
# 1                                 MSI Titan GT77-12UHS
# 2                                     Alienware X17 R2
# 3                Acer Predator Triton 500 SE PT516-52s
# 4                              Omen By HP (16-B1371TX)
# 5        Acer Predator Helios 300 AN515-45 (NH.QBRSI.0
# 6                           MSI Delta 15 (A5EFK-083IN)
# 7                              Omen By HP (16-C0141AX)
# 8                    Lenovo Legion 5i Pro (82RF00MGIN)
# 9        Alienware M15 R5 Ryzen Edition Icc-C780001win
# 10                    Lenovo Slim 7 Gen 6 (82K8002JIN)
#
#                                                  Processor  \
# Sr. No.
# 1         12th Gen Intel Core i9-12900HX 16 core processor
# 2        12th Gen Intel Core i9-12900H 14 core processo...
# 3        12th Gen Intel Core i7-12700H 14 core processo...
# 4        12th Gen Intel Core i7-12700H 14 core processo...
# 5                      AMD Ryzen 9-5900HX 8 core processor
# 6        AMD 5th Gen Ryzen 9-5900HX 8 core processor wi...
# 7        AMD Ryzen™ 9 5900HX 8 core processor with 3.3 ...
# 8        12th Gen Intel Core i7-12700H 14 core processo...
# 9        AMD Ryzen R7-5800H 8 core processor with 4.40 ...
# 10       Lenovo Ryzen 7-5800H processor with 3.2 GHz cl...
#
#                                                  Display               OS  \
# Sr. No.
# 1        17.3″ (3840 x 2160) screen, 120 Hz refresh rate  Windows 11 Home
# 2        17.3″ (1920 x 1080) screen, 360 Hz refresh rate  Windows 11 Home
# 3          16″ (2560 x 1600) screen, 240 Hz refresh rate  Windows 11 Home
# 4                             16.1″ (2560 x 1440) screen  Windows 11 Home
# 5        15.6″ (2560 x 1440) screen, 165 Hz refresh rate  Windows 11 Home
# 6         15.6″ (1920 x 1080) screen, 240Hz refresh rate  Windows 11 Home
# 7                             16.1″ (2560 x 1440) screen  Windows 11 Home
# 8          16″ (2560 x 1600) screen, 165 Hz refresh rate  Windows 11 Home
# 9         15.6″ (1920 x 1080) screen, 165Hz refresh rate  Windows 11 Home
# 10                     15.6″ screen, 165 Hz refresh rate  Windows 11 Home
#
#                               Memory  \
# Sr. No.
# 1          64 GB DDR5 RAM & 2 TB SSD
# 2          32 GB DDR5 RAM & 1 TB SSD
# 3          32 GB DDR5 RAM & 2 TB SSD
# 4           8 GB DDR5 RAM & 1 TB SSD
# 5        16 GB DDR4 RAM & 512 GB SSD
# 6          16 GB DDR4 RAM & 1 TB SSD
# 7         16 GB DDR4 RAM & 1 TB NVMe
# 8          16 GB DDR5 RAM & 1 TB SSD
# 9        16 GB DDR4 RAM & 512 GB SSD
# 10         16 GB DDR4 RAM & 1 TB SSD
#
#                                         Graphics Processor  \
# Sr. No.
# 1        16 GB DDR6 NVIDIA GeForce RTX 3080 Ti Graphics...
# 2        16 GB DDR6 NVIDIA GEFORCE RTX 3080 Ti Graphics...
# 3        8 GB DDR6 NVIDIA GeForce RTXTM 3070 Ti Graphic...
# 4         8 GB GDDR6 NVIDIA GeForce RTX 3070 Graphics card
# 5          8 GB DDR6 NVIDIA GeForce RTX 3070 Graphics card
# 6             10 GB DDR6 AMD Radeon RX 6700M Graphics card
# 7            8 GB GDDR6 AMD Radeon™ RX 6600M Graphics card
# 8          6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card
# 9          6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card
# 10       6 GB DDR6 NVIDIA GeForce 3060 Max-Q Graphics card
#
#                                    Dimension           Weight  \
# Sr. No.
# 1               397 x 330 x 23 mm dimension     3.3 kg weight
# 2               299 x 359 x 21 mm dimension    2.96 kg weight
# 3             358 x 262 x 19.9 mm dimension     2.4 kg weight
# 4               369 x 248 x 23 mm dimension    2.32 kg weight
# 5             363 x 255 x 23.9 mm dimension     2.4 kg weight
# 6               357 x 247 x 19 mm dimension     1.9 kg weight
# 7           36.92 x 24.8 x 2.3 mm dimension     2.3 kg weight
# 8               360 x 264 x 20 mm dimension    2.49 kg weight
# 9        356.2 x 272.5 x 22.85 mm dimension    2.69 kg weight
# 10              356 x 252 x 16 mm dimension     1.9 kg weight
#
#                                                        URL
# Sr. No.
# 1        https://www.digit.in/laptops/msi-titan-gt77-12...
# 2        https://www.digit.in/laptops/dell-new-alienwar...
# 3        https://www.digit.in/laptops/acer-predator-tri...
# 4        https://www.digit.in/laptops/omen-by-hp-16-b13...
# 5        https://www.digit.in/laptops/acer-nitro-5-an51...
# 6        https://www.digit.in/laptops/msi-delta-15-5th-...
# 7        https://www.digit.in/laptops/hp-omen-16-c0141a...
# 8        https://www.digit.in/laptops/lenovo-legion-5-p...
# 9        https://www.digit.in/laptops/dell-alienware-m1...
# 10       https://www.digit.in/laptops/lenovo-legion-s7-...

# %% [markdown]
# ### Q8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"chromedriver.exe")

#open the page in automated chrome browse

driver.get('https://www.forbes.com/billionaires/')
time.sleep(2)

# %%
#close popup window

try:
    popup = driver.find_element(By.XPATH,'/html/body/div[7]/div/button')
    popup.click()
except NoSuchElementException:
    print('Popup Window is not present')

# %%
# Empty list to scrap data
rank =[]
name=[]
net_worth=[]
age=[]
citizenship=[]
source=[]
industry=[]

# %%
# Extracting Rank No
rank_tag =driver.find_elements(By.XPATH,'//div[@class="rank"]')
for i in rank_tag:
    rank.append(i.text.split(".")[0])

# %%
# Extacting name
name_tag = driver.find_elements(By.XPATH,'//div[@class="personName"]/div')
for i in name_tag:
    name.append(i.text)
len(name)
# Out:
# 200

# %%
#Extracting Net worth
net_tag =driver.find_elements(By.XPATH,'//div[@class="netWorth"]/div')
for i in net_tag:
    net_worth.append(i.text)
len(net_worth)
# Out:
# 200

# %%
# Extracting Age
age_tag =driver.find_elements(By.XPATH,'//div[@class="age"]')
for i in age_tag:
    age.append(i.text)
len(age)
# Out:
# 200

# %%
# Extracting Citizenship
citizen_tag =driver.find_elements(By.XPATH,'//div[@class="countryOfCitizenship"]')
for i in citizen_tag:
    citizenship.append(i.text)
    
len(citizenship)
# Out:
# 200

# %%
# Extracting Source
try:
    source_tag =driver.find_elements(By.XPATH,'//div[@class="source-column"]')
    for i in source_tag:
        source.append(i.text)
except:
    source_tag =driver.find_elements(By.XPATH,'//*[@id="jeff-bezos"]/div[6]/div/div[1]')
    source.append(i.text)
    
len(source)
# Out:
# 200

# %%
# Extracting Industry
ind_tag =driver.find_elements(By.XPATH,"//div[@class='category']//div")
for i in ind_tag:
    industry.append(i.text)
len(industry)
# Out:
# 200

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(rank,name,net_worth,age,citizenship,source,industry))

data= pd.DataFrame (data_list,
    columns =['Rank', 'Name','Net Worth','Age','Citizenship','Source','Industry'], 
                    index= pd.RangeIndex(start=1, stop=201, name='Sr. No.'))

#Print the required data

data.to_csv("Digit_laptop_details.csv", index= False)

print("Details of all the available details of best gaming laptops from digit.in:\n")
data
# Out:
# Details of all the available details of best gaming laptops from digit.in:
#         Rank                      Name Net Worth Age    Citizenship  \
# Sr. No.
# 1          1                 Elon Musk    $219 B  50  United States
# 2          2                Jeff Bezos    $171 B  58  United States
# 3          3  Bernard Arnault & family    $158 B  73         France
# 4          4                Bill Gates    $129 B  66  United States
# 5          5            Warren Buffett    $118 B  91  United States
# ...      ...                       ...       ...  ..            ...
# 196      192    Marcel Herrmann Telles   $10.3 B  72         Brazil
# 197      197                Leon Black     $10 B  70  United States
# 198      197                Joe Gebbia     $10 B  40  United States
# 199      197              David Geffen     $10 B  79  United States
# 200      197                Yu Renrong     $10 B  56          China
#
#                         Source               Industry
# Sr. No.
# 1                Tesla, SpaceX             Automotive
# 2                       Amazon             Technology
# 3                         LVMH       Fashion & Retail
# 4                    Microsoft             Technology
# 5           Berkshire Hathaway  Finance & Investments
# ...                        ...                    ...
# 196                       beer        Food & Beverage
# 197             private equity  Finance & Investments
# 198                     Airbnb             Technology
# 199      movies, record labels  Media & Entertainment
# 200             semiconductors          Manufacturing
#
# [200 rows x 7 columns]

# %% [markdown]
# ### Q9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"chromedriver.exe")

#open the page in automated chrome browse

driver.get('https://www.youtube.com')
time.sleep(2)

# %%
# Finding search menu
search=driver.find_element(By.XPATH,'//input[@id="search"]') 

#Putting input video name by user

search.send_keys('The Kid LAROI, Justin Bieber - STAY')

# Finding Search button and clicking

button=driver.find_element(By.XPATH,'//button[@id="search-icon-legacy"]/yt-icon')  
button.click()
time.sleep(2)

# %%
# Clicking on video

search_video = driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-search/div[1]/ytd-two-column-search-results-renderer/div/ytd-section-list-renderer/div[2]/ytd-item-section-renderer[2]/div[3]/ytd-video-renderer[1]/div[1]/div/div[1]/div/h3/a')
search_video.click()
time.sleep(2)

# %%
from time import sleep

# Loading all comments
i = 1 
while True:
    i += 500
    driver.execute_script(f"window.scrollTo(0, {i});")
        
    all_box = driver.find_elements(By.XPATH,'//ytd-comment-thread-renderer')
    
    sleep(1)
    
    if len(all_box) > 500:
        break

# %%
full = []
for i in all_box:
    comment = i.find_element(By.XPATH,'.//ytd-expander[@id="expander"]').text
    upvote = i.find_element(By.XPATH,'.//span[@id="vote-count-middle"]').text
    time = i.find_element(By.XPATH,'.//div[@id="header-author"]//yt-formatted-string/a').text
    
    full.append({
        'comment' : comment,
        'upvote' : upvote,
        'time' : time
    })
    
data = pd.DataFrame(full)
data
# Out:
#                                                comment upvote  \
# 0                                                        226K
# 1    Пишем комментарии пожелания не стесняемся ребя...      9
# 2                  ずっと探してたから見つけて感動\n曲名知らなかったから調べまくりました      7
# 3    They both seem blood brothers, their voice and...     10
# 4                               Essa música é tudo!!!     420
# ..                                                 ...    ...
# 502  still no. 1 on billboard congrats kid laroi an...    138
# 503  Finally found it, listened to it tripping and ...
# 504  It's a year to this song time pass so fast I k...      1
# 505                                       The song is
# 506                                  i  like this song
#
#                      time
# 0              1 year ago
# 1            21 hours ago
# 2              8 days ago
# 3            19 hours ago
# 4              1 year ago
# ..                    ...
# 502            1 year ago
# 503           3 weeks ago
# 504  13 days ago (edited)
# 505           10 days ago
# 506           3 weeks ago
#
# [507 rows x 3 columns]

# %%
data_final= data[0:500]
#Print the required data

data_final.to_csv("Digit_laptop_details.csv", index= True)

print("Details of  500 Comments, upvote and time when comment was posted from any YouTube Video:\n")
data_final
# Out:
# Details of  500 Comments, upvote and time when comment was posted from any YouTube Video:
#                                                comment upvote          time
# 0                                                        226K    1 year ago
# 1    Пишем комментарии пожелания не стесняемся ребя...      9  21 hours ago
# 2                  ずっと探してたから見つけて感動\n曲名知らなかったから調べまくりました      7    8 days ago
# 3    They both seem blood brothers, their voice and...     10  19 hours ago
# 4                               Essa música é tudo!!!     420    1 year ago
# ..                                                 ...    ...           ...
# 495                                 STAY now 2 billion      1    9 days ago
# 496  Excelente canción y vídeo de The Kid LAROI y J...    448    1 year ago
# 497                              Очень необычная песня      1   2 weeks ago
# 498                               вообще классный трек           6 days ago
# 499               this song help me survive Quarantine          10 days ago
#
# [500 rows x 3 columns]

# %% [markdown]
# ### Q10.Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
# Connecting to webdriver

driver= webdriver.Chrome("chromedriver.exe")

#open the page in automated chrome browse

driver.get(" https://www.hostelworld.com/")

# %%
# Finding search menu

search = driver.find_element(By.XPATH,'//input[@id="location-text-input-field"]')
search.send_keys("London")

# %%
# clicking london

london = driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[1]/div/div/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]')
london.click()

# %%
#search for london

letsgo= driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[1]/div/div/div[4]/div/div[2]/div/div[5]/button')
letsgo.click()

# %%
#empty list for storing required data

hostel_name = []
distance = []
facilities =[]
url = []

# %%
#fetching hostel name
try:
    name_tags = driver.find_elements(By.XPATH,'//h2[@class="title title-6"]/a')
    for i in name_tags:
        hostel_name.append(i.text)
except NoSuchElementException:
    hostel_name.append('-')

# %%
len(hostel_name)
# Out:
# 15

# %%
#fetching distance
try:
    distance_tags = driver.find_elements(By.XPATH,'//span[@class="description"]')
    for i in distance_tags:
        distance.append(i.text.split("-")[1])
except NoSuchElementException:
    distance.append('-')

# %%
len(distance)
# Out:
# 15

# %%
url_tags =driver.find_elements(By.XPATH,'//h2[@class="title title-6"]/a')
for i in url_tags:
    x=i.get_attribute('href')
    url.append(x)
url
# Out:
# ['https://www.hostelworld.com/pwa/hosteldetails.php/Urbany-Hostel-London/London/303427?from=2022-09-28&to=2022-10-01&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Safestay-London-Elephant-Castle/London/55551?from=2022-09-28&to=2022-10-01&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Saint-James-Backpackers/London/70909?from=2022-09-28&to=2022-10-01&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Oasis-Female-Only/London/504?from=2022-09-28&to=2022-10-01&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Selina-Camden/London/310274?from=2022-09-28&to=2022-10-01&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Britannia-Inn-Hotel/London/47955?from=2022-09-28&to=2022-10-01&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/City-Hotel-Carlton/London/27551?from=2022-09-28&to=2022-10-01&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Elmwood-Hotel/London/34338?from=2022-09-28&to=2022-10-01&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Kip-Hotel/London/266789?from=2022-09-28&to=2022-10-01&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/London-House-Hotel/London/529?from=2022-09-28&to=2022-10-01&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Tony-s-House-Hotel/London/8503?from=2022-09-28&to=2022-10-01&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Hotel-Shepherds-Bush-London/London/308621?from=2022-09-28&to=2022-10-01&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Cranbrook-Hotel/London/10144?from=2022-09-28&to=2022-10-01&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Hyde-Park-Court-Hotel/London/5107?from=2022-09-28&to=2022-10-01&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Park-Hotel-Essex/London/10143?from=2022-09-28&to=2022-10-01&guests=2']

# %%
len(url)
# Out:
# 15

# %%
#fetching distance
try:
    facilities_tags = driver.find_elements(By.XPATH,'//div[@class="facilities-label facilities"]')
    for i in facilities_tags:
        facilities.append(i.text.replace("\n",","))
except NoSuchElementException:
    facilities.append('-')
facilities
# Out:
# ['Free WiFi,Follows Covid-19 sanitation guidance',
#  'Free WiFi,Follows Covid-19 sanitation guidance',
#  'Free WiFi,Free Breakfast,Follows Covid-19 sanitation guidance',
#  'Free WiFi,Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free Breakfast,Follows Covid-19 sanitation guidance',
#  '',
#  '',
#  'Free WiFi',
#  'Free WiFi',
#  'Free Breakfast',
#  'Free WiFi,Follows Covid-19 sanitation guidance',
#  'Free Breakfast,Follows Covid-19 sanitation guidance',
#  'Free WiFi,Free Breakfast',
#  'Free Breakfast,Follows Covid-19 sanitation guidance']

# %%
len(facilities)
# Out:
# 15

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(hostel_name,distance,facilities, url))

data= pd.DataFrame (data_list,
    columns =['hostel_name','distance','facilities', 'url'], 
                    index= pd.RangeIndex(start=1, stop=16, name='Sr. No.'))

#Print the required data

data.to_csv("hotels_details.csv", index= False)

print("Details of all the available Hostels from https://www.hostelworld.com/ in “London” location:\n")
data
# Out:
# Details of all the available Hostels from https://www.hostelworld.com/ in “London” location:
#                                 hostel_name                  distance  \
# Sr. No.
# 1                      Urbany Hostel London    5.4km from city centre
# 2         Safestay London Elephant & Castle    1.7km from city centre
# 3                   Saint James Backpackers    5.5km from city centre
# 4        St Christopher's Oasis-Female Only    1.8km from city centre
# 5                             Selina Camden    5.5km from city centre
# 6                       Britannia Inn Hotel   14.5km from city centre
# 7                        City Hotel Carlton    1.8km from city centre
# 8                             Elmwood Hotel    3.2km from city centre
# 9                                 Kip Hotel    6.8km from city centre
# 10                       London House Hotel    5.3km from city centre
# 11                       Tony's House Hotel    4.3km from city centre
# 12              Hotel Shepherds Bush London    7.6km from city centre
# 13                          Cranbrook Hotel   14.8km from city centre
# 14                    Hyde Park Court Hotel    4.3km from city centre
# 15                         Park Hotel Essex   24.1km from city centre
#
#                                                 facilities  \
# Sr. No.
# 1           Free WiFi,Follows Covid-19 sanitation guidance
# 2           Free WiFi,Follows Covid-19 sanitation guidance
# 3        Free WiFi,Free Breakfast,Follows Covid-19 sani...
# 4           Free WiFi,Follows Covid-19 sanitation guidance
# 5                                                Free WiFi
# 6        Free Breakfast,Follows Covid-19 sanitation gui...
# 7
# 8
# 9                                                Free WiFi
# 10                                               Free WiFi
# 11                                          Free Breakfast
# 12          Free WiFi,Follows Covid-19 sanitation guidance
# 13       Free Breakfast,Follows Covid-19 sanitation gui...
# 14                                Free WiFi,Free Breakfast
# 15       Free Breakfast,Follows Covid-19 sanitation gui...
#
#                                                        url
# Sr. No.
# 1        https://www.hostelworld.com/pwa/hosteldetails....
# 2        https://www.hostelworld.com/pwa/hosteldetails....
# 3        https://www.hostelworld.com/pwa/hosteldetails....
# 4        https://www.hostelworld.com/pwa/hosteldetails....
# 5        https://www.hostelworld.com/pwa/hosteldetails....
# 6        https://www.hostelworld.com/pwa/hosteldetails....
# 7        https://www.hostelworld.com/pwa/hosteldetails....
# 8        https://www.hostelworld.com/pwa/hosteldetails....
# 9        https://www.hostelworld.com/pwa/hosteldetails....
# 10       https://www.hostelworld.com/pwa/hosteldetails....
# 11       https://www.hostelworld.com/pwa/hosteldetails....
# 12       https://www.hostelworld.com/pwa/hosteldetails....
# 13       https://www.hostelworld.com/pwa/hosteldetails....
# 14       https://www.hostelworld.com/pwa/hosteldetails....
# 15       https://www.hostelworld.com/pwa/hosteldetails....
