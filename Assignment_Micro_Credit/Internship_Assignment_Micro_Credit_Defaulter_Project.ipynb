# %% [markdown]
# # Micro_Credit_Defaulter_Project :-  Flip Robo Technologies   |
#
# # Internship Batch No-31
#
#
# #### Submitted by: Tamali Saha (tamali428@gmail.com)
#
# ## Problem Statement:

# %% [markdown]
# A Microfinance Institution (MFI) is an organization that offers financial services to low income populations. MFS becomes very useful when targeting especially the unbanked poor families living in remote areas with not much sources of income. The Microfinance services (MFS) provided by MFI are Group Loans, Agricultural Loans, Individual Business Loans and so on.
# Many microfinance institutions (MFI), experts and donors are supporting the idea of using mobile financial services (MFS) which they feel are more convenient and efficient, and cost saving, than the traditional high-touch model used since long for the purpose of delivering microfinance services. Though, the MFI industry is primarily focusing on low income families and are very useful in such areas, the implementation of MFS has been uneven with both significant challenges and successes.
# Today, microfinance is widely accepted as a poverty-reduction tool, representing $70 billion in outstanding loans and a global outreach of 200 million clients.
# We are working with one such client that is in Telecom Industry. They are a fixed wireless telecommunications network provider. They have launched various products and have developed its business and organization based on the budget operator model, offering better products at Lower Prices to all value conscious customers through a strategy of disruptive innovation that focuses on the subscriber.
# They understand the importance of communication and how it affects a person’s life, thus, focusing on providing their services and products to low income families and poor customers that can help them in the need of hour.
# They are collaborating with an MFI to provide micro-credit on mobile balances to be paid back in 5 days. The Consumer is believed to be defaulter if he deviates from the path of paying back the loaned amount within the time duration of 5 days. For the loan amount of 5 (in Indonesian Rupiah), payback amount should be 6 (in Indonesian Rupiah), while, for the loan amount of 10 (in Indonesian Rupiah), the payback amount should be 12 (in Indonesian Rupiah).
# The sample data is provided to us from our client database. It is hereby given to you for this exercise. In order to improve the selection of customers for the credit, the client wants some predictions that could help them in further investment and improvement in selection of customers.
#
# Exercise:
# Build a model which can be used to predict in terms of a probability for each loan transaction, whether the customer will be paying back the loaned amount within 5 days of insurance of loan. In this case, Label ‘1’ indicates that the loan has been payed i.e. Non- defaulter, while, Label ‘0’ indicates that the loan has not been payed i.e. defaulter.
# Points to Remember:
#
#
# •	There are no null values in the dataset.
# •	There may be some customers with no loan history.
# •	The dataset is imbalanced. Label ‘1’ has approximately 87.5% records, while, label ‘0’ has approximately 12.5% records.
# •	For some features, there may be values which might not be realistic. You may have to observe them and treat them with a suitable explanation.
# •	You might come across outliers in some features which you need to handle as per your understanding. Keep in mind that data is expensive and we cannot lose more than 7-8% of the data.
#
# Find Enclosed the Data Description File and The Sample Data for the Modeling Exercise.

# %% [markdown]
# - **label** : Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure}
# - **msisdn** : mobile number of user
# - **aon** : age on cellular network in days
# - **daily_decr30** : Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)
# - **daily_decr90** : Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah)
# - **rental30** : Average main account balance over last 30 days
# - **rental90** : Average main account balance over last 90 days
# - **last_rech_date_ma** : Number of days till last recharge of main account
# - **last_rech_date_da**: Number of days till last recharge of data account
# - **last_rech_amt_ma** : Amount of last recharge of main account (in Indonesian Rupiah)
# - **cnt_ma_rech30** : Number of times main account got recharged in last 30 days
# - **fr_ma_rech30** : Frequency of main account recharged in last 30 days
# - **sumamnt_ma_rech30** : Total amount of recharge in main account over last 30 days (in Indonesian Rupiah)
# - **medianamnt_ma_rech30** : Median of amount of recharges done in main account over last 30 days at user level (in Indonesian Rupiah)
# - **medianmarechprebal30** : Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah)
# - **cnt_ma_rech90** : Number of times main account got recharged in last 90 days
# - **fr_ma_rech90** : Frequency of main account recharged in last 90 days
# - **sumamnt_ma_rech90** : Total amount of recharge in main account over last 90 days (in Indonasian Rupiah)
# - **medianamnt_ma_rech90** : Median of amount of recharges done in main account over last 90 days at user level (in Indonasian Rupiah)
# - **medianmarechprebal90** : Median of main account balance just before recharge in last 90 days at user level (in Indonasian Rupiah)
# - **cnt_da_rech30** : Number of times data account got recharged in last 30 days
# - **fr_da_rech30**: Frequency of data account recharged in last 30 days
# - **cnt_da_rech90** : Number of times data account got recharged in last 90 days
# - **fr_da_rech90** : Frequency of data account recharged in last 90 days
# - **cnt_loans30** : Number of loans taken by user in last 30 days
# - **amnt_loans30** : Total amount of loans taken by user in last 30 days
# - **maxamnt_loans30** : maximum amount of loan taken by the user in last 30 days
# - **medianamnt_loans30** : Median of amounts of loan taken by the user in last 30 days
# - **cnt_loans90** : Number of loans taken by user in last 90 days
# - **amnt_loans90** : Total amount of loans taken by user in last 90 days
# - **maxamnt_loans90** : maximum amount of loan taken by the user in last 90 days
# - **medianamnt_loans90** : Median of amounts of loan taken by the user in last 90 days
# - **payback30** : Average payback time in days over last 30 days
# - **payback90** : Average payback time in days over last 90 days
# - **pcircle** : telecom circle
# - **pdate** : date

# %% [markdown]
# ### Import Necessary libraries:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split

# %%
# import train data and check 6 different samples

data = pd.read_csv('Micro_Credit_Defaulter.csv')
data.sample(n=6)
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 96789        96790      1  18724I88658   103.0  74721.000000  74824.400000
# 192462      192463      1  92440I90585  1113.0    108.951333    108.951333
# 142730      142731      1  15742I84453   664.0     17.552000     17.552000
# 161204      161205      1  37075I89239   131.0   4641.000000   6100.000000
# 2919          2920      1  65815I88690  1149.0   9006.000000  16509.760000
# 157662      157663      1  65381I70377   586.0      3.450000      3.450000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 96789   16538.63  16254.83                2.0                0.0  ...
# 192462    -73.92    -73.92                0.0                0.0  ...
# 142730    133.04    133.04              -25.0                0.0  ...
# 161204    299.70   1816.79                3.0                0.0  ...
# 2919      900.85   3136.73                5.0                0.0  ...
# ...

# %% [markdown]
# ### Checking Shape:

# %%
# checking shapes of train and test data

print ("No of rows of dataset:",data.shape[0])
print ("No of Columns of dataset:",data.shape[1])
# Out:
# No of rows of dataset: 209593
# No of Columns of dataset: 37

# %% [markdown]
# #### Observations:
#
# This Dataset has 209593 rows and 37 columns.
#
# Let's study the column's names and their charectaristics.
#
# ## **Preprocessing of train data:**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %%
data.nunique()
# Out:
# Unnamed: 0              209593
# label                        2
# msisdn                  186243
# aon                       4507
# daily_decr30            147025
# daily_decr90            158669
# rental30                132148
# rental90                141033
# last_rech_date_ma         1186
# last_rech_date_da         1174
# last_rech_amt_ma            70
# cnt_ma_rech30               71
# fr_ma_rech30              1083
# sumamnt_ma_rech30        15141
# medianamnt_ma_rech30       510
# medianmarechprebal30     30428
# cnt_ma_rech90              110
# fr_ma_rech90                89
# sumamnt_ma_rech90        31771
# medianamnt_ma_rech90       608
# medianmarechprebal90     29785
# cnt_da_rech30             1066
# fr_da_rech30              1072
# cnt_da_rech90               27
# fr_da_rech90                46
# cnt_loans30                 40
# amnt_loans30                48
# maxamnt_loans30           1050
# medianamnt_loans30           6
# cnt_loans90               1110
# ...

# %% [markdown]
# #### Observations:
#
# 1. There are total 3 categorical columns among 37 columns.
# 2. Unnamed: 0 is unnecessary column with 209593 unique value. Let's drop it.
# 3. Target feature is **label** and it is int datatype.  But it is binary. So the problem is a **Classification problem.**
# 4. pcircle is single unique value which is 2016. Let's drop it.
# 5. pdate is a object datatype. Need to convert in in date format.

# %% [markdown]
# ### Change Date Datatype (pdate) :

# %%
data['pdate']=pd.to_datetime(data['pdate'])

# %%
data['p_day'] = data['pdate'].dt.day
data['p_month'] = data['pdate'].dt.month
data['p_year'] = data['pdate'].dt.year

data.drop(['pdate'],axis=1,inplace=True)

# %% [markdown]
# ### Checking Null:

# %%
null_val= data.isna().sum().any()
null_val
# Out:
# False

# %% [markdown]
# #### Observations:
#
# Null values are present in the total dataset.

# %% [markdown]
# ### Statistical Matrix Evaluation:

# %%
data.describe().T
# Out:
#                          count           mean           std           min  \
# Unnamed: 0            209593.0  104797.000000  60504.431823      1.000000
# label                 209593.0       0.875177      0.330519      0.000000
# aon                   209593.0    8112.343445  75696.082531    -48.000000
# daily_decr30          209593.0    5381.402289   9220.623400    -93.012667
# daily_decr90          209593.0    6082.515068  10918.812767    -93.012667
# rental30              209593.0    2692.581910   4308.586781 -23737.140000
# rental90              209593.0    3483.406534   5770.461279 -24720.580000
# last_rech_date_ma     209593.0    3755.847800  53905.892230    -29.000000
# last_rech_date_da     209593.0    3712.202921  53374.833430    -29.000000
# last_rech_amt_ma      209593.0    2064.452797   2370.786034      0.000000
# cnt_ma_rech30         209593.0       3.978057      4.256090      0.000000
# fr_ma_rech30          209593.0    3737.355121  53643.625172      0.000000
# ...

# %%
data.describe(include=object)
# Out:
#              msisdn pcircle
# count        209593  209593
# unique       186243       1
# top     04581I85330     UPW
# freq              7  209593

# %% [markdown]
# #### Observations:
#
# 1. Null is not present.
# 2. Seems outliers are present as there is a difference between 75% and max of some features.
# 3. All p_year is single unique value which is 2016. Let's drop year column.
# 4. has frequency 7 that is 1 mobile number entired max 7 times.
# 5. Some features has a lot of difference between 75% and maximum value. Seems outliers are present in the dataset.
# 6. Some features has negative values in minimum column. They are aon, daily_decr30, daily_decr90 ,rental30, rental90, last_rech_date_ma, last_rech_date_da, medianmarechprebal90, medianmarechprebal30. Let's explore those columns further.
# 7. Maximum aon (age on cellular network in days) value is 999860.755168 and the minimum is -48.
#
# ### Drop unnecessary data:

# %%
data['pcircle'].value_counts()
# Out:
# UPW    209593
# Name: pcircle, dtype: int64

# %%
data.drop(['Unnamed: 0', 'p_year','pcircle'],axis=1,inplace=True)

# %% [markdown]
# ### Checking duplicate:

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data.duplicated('msisdn').sum()
# Out:
# 23350

# %% [markdown]
# #### Observations:
#
# 1. There 1 row with completely duplicate values of all features.
# 2. There 23350 rows with duplicate mobile number. Seems same mobile number is switch to other customers.

# %%
data.drop_duplicates(keep='first',inplace=True)
data.shape
# Out:
# (209592, 36)

# %% [markdown]
# ### Removal of Negative values:

# %%
data['aon'].describe()
# Out:
# count    209592.000000
# mean       8112.380399
# std       75696.261220
# min         -48.000000
# 25%         246.000000
# 50%         527.000000
# 75%         982.000000
# max      999860.755168
# Name: aon, dtype: float64

# %% [markdown]
# #### Observations:
#
# 1. Here maximum is 999860.755168 and the minimum is -48.  Let's convert maximum value in years.
# 2. The minimum value is wrongly entered.

# %%
print( "Maximum value of 'aon' in years :", 999860/365)
# Out:
# Maximum value of 'aon' in years : 2739.3424657534247

# %% [markdown]
# #### Observations:
#
# Maximum value of 'aon' in years : 2739.34 year which is not possible at all.

# %%
print(" No of entries with negetive aon value: ")
data[data['aon']<0].value_counts().sum()
# Out:
#  No of entries with negetive aon value:
# 1539

# %% [markdown]
# #### Observations:
#
# There are 1539 entries with value less than 0.  In this particular column, a huge problem is arised due to wrong entry of data. Let's minimize the chance of error with some assumptions:
#
# 1. All negative values are typing by mistake "-" (minus) in front of original value. Negative values are converted into absolute value (positive) to correct error.
# 2. Upper limit of these features handle by outlier removal.

# %%
data['aon']=abs(data['aon'])

# %%
data['aon'].describe()
# Out:
# count    209592.000000
# mean       8112.845675
# std       75696.211355
# min           1.000000
# 25%         246.000000
# 50%         527.000000
# 75%         982.000000
# max      999860.755168
# Name: aon, dtype: float64

# %% [markdown]
# #### Observations:
#
# Let's apply this technique to all negetive minimum values column.

# %%
data['daily_decr30']=abs(data['daily_decr30'])
data['daily_decr90']=abs(data['daily_decr90'])
data['rental30']=abs(data['rental30'])
data['rental90']=abs(data['rental90'])
data['last_rech_date_ma']=abs(data['last_rech_date_ma'])
data['last_rech_date_da']=abs(data['last_rech_date_da'])

# %%
data.describe().T
# Out:
#                          count          mean           std    min  \
# label                 209592.0      0.875177      0.330519    0.0
# aon                   209592.0   8112.845675  75696.211355    1.0
# daily_decr30          209592.0   5381.442003   9220.627165    0.0
# daily_decr90          209592.0   6082.558196  10918.820723    0.0
# rental30              209592.0   2715.373669   4294.267480    0.0
# rental90              209592.0   3509.498048   5754.644314    0.0
# last_rech_date_ma     209592.0   3756.143760  53906.000830    0.0
# last_rech_date_da     209592.0   3712.222512  53374.960014    0.0
# last_rech_amt_ma      209592.0   2064.458973   2370.790003    0.0
# cnt_ma_rech30         209592.0      3.978053      4.256099    0.0
# fr_ma_rech30          209592.0   3737.372947  53643.752523    0.0
# sumamnt_ma_rech30     209592.0   7704.496570  10139.645685    0.0
# medianamnt_ma_rech30  209592.0   1812.819258   2070.869474    0.0
# ...

# %% [markdown]
# #### Observations:
#
# 1. All negative min value except medianmarechprebal90, medianmarechprebal30 are deleted by replacing with abs of corresponding  values.
# 2. medianmarechprebal90, medianmarechprebal30 are still negative. Let's explore this.
#
# #### Explore medianmarechprebal90, medianmarechprebal30:
#
# - **medianmarechprebal30** : Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah)**
# - **medianmarechprebal90** : Median of main account balance just before recharge in last 90 days at user level (in Indonasian Rupiah)

# %%
data['medianmarechprebal30'].describe()
# Out:
# count    209592.000000
# mean       3851.945862
# std       54006.502647
# min        -200.000000
# 25%          11.000000
# 50%          33.900000
# 75%          83.000000
# max      999479.419319
# Name: medianmarechprebal30, dtype: float64

# %% [markdown]
# The median of main account balance can be negative. Let's keep this.

# %% [markdown]
# #### Explore maxamnt_loans30 and maxamnt_loans90:
#
# - **maxamnt_loans30** : maximum amount of loan taken by the user in last 30 days
# - **maxamnt_loans90** : maximum amount of loan taken by the user in last 90 days

# %%
data['maxamnt_loans30'].describe()
# Out:
# count    209592.000000
# mean        274.660029
# std        4245.274734
# min           0.000000
# 25%           6.000000
# 50%           6.000000
# 75%           6.000000
# max       99864.560864
# Name: maxamnt_loans30, dtype: float64

# %%
data['maxamnt_loans90'].describe()
# Out:
# count    209592.000000
# mean          6.703138
# std           2.103869
# min           0.000000
# 25%           6.000000
# 50%           6.000000
# 75%           6.000000
# max          12.000000
# Name: maxamnt_loans90, dtype: float64

# %%
data['maxamnt_loans90'].value_counts()
# Out:
# 6     180944
# 12     26605
# 0       2043
# Name: maxamnt_loans90, dtype: int64

# %% [markdown]
# #### Observations:
#
# 1. Here, maxamnt_loans30 and maxamnt_loans90 are same type of datatype. The data structure of this two column are same. So it is clear that, the repay amount be 0,6,12. Let's replace values greater than 12 into category of zero.
#
# - **Assumption:**  loan amount greater than 12 will be replaced by zero(0).

# %%
data.loc[(data['maxamnt_loans30'] != 6.0) & (data['maxamnt_loans30'] != 12.0) & (data['maxamnt_loans30']!=0.0), 'maxamnt_loans30']=0.0
data['maxamnt_loans30'].value_counts()
# Out:
# 6.0     179192
# 12.0     26109
# 0.0       4291
# Name: maxamnt_loans30, dtype: int64

# %% [markdown]
# ### Final data after cleaning:

# %%
data.shape
# Out:
# (209592, 36)

# %%
data.columns.to_series().groupby(data.dtypes).groups
# Out:
# {int64: ['label', 'last_rech_amt_ma', 'cnt_ma_rech30', 'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30', 'amnt_loans90', 'maxamnt_loans90', 'p_day', 'p_month'], float64: ['aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da', 'fr_ma_rech30', 'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30', 'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90'], object: ['msisdn']}

# %%
float_num_features= ['aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90', 'last_rech_date_ma', 
               'last_rech_date_da', 'fr_ma_rech30', 'sumamnt_ma_rech30', 'medianamnt_ma_rech30',
               'medianmarechprebal30', 'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30', 
               'fr_da_rech30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'medianamnt_loans90', 
               'payback30', 'payback90']
int_num_features= ['last_rech_amt_ma', 'cnt_ma_rech30', 'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90', 
                   'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30', 'amnt_loans90', 'maxamnt_loans90', 
                   'p_day', 'p_month']
cat_features= ['msisdn']

# %% [markdown]
# ## 1. Exploratory Data Analysis(EDA):
#
# ### Exploration of target variable:

# %%
data["label"].value_counts()
# Out:
# 1    183430
# 0     26162
# Name: label, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(20,6))

data['label'].value_counts().plot.pie(autopct='%3.1f%%', textprops ={ 'fontweight': 'bold','fontsize':10}, ax=ax[0])
ax[0].set_title('label Distribution', fontsize=15,fontweight ='bold')
sns.countplot('label',data=data ,ax=ax[1])
ax[1].set_title('label Distribution',fontsize=15,fontweight ='bold')
ax[1].set_xlabel('label',fontsize=15)
plt.show()

# %% [markdown]
# #### Observations:
#
# - **Here Label ‘1’ indicates that the loan has been payed i.e. Non- defaulter, while, Label ‘0’ indicates that the loan has not been payed i.e. defaulter.**
#
# 1. Maximum customers around 87.5% are Non-defaulter(label = 1).
# 2. Here the dataset is imbalanced.
#
# ### Exploration of different features with label:

# %% [markdown]
# #### For p_day:

# %%
f,ax=plt.subplots(1,2,figsize=(20,6))

data['p_day'].value_counts().plot.pie(autopct='%3.1f%%', textprops ={ 'fontweight': 'bold','fontsize':10}, ax=ax[0])
ax[0].set_title('p_day Distribution', fontsize=15,fontweight ='bold')
sns.countplot('p_day',data=data,ax=ax[1])
ax[1].set_title('p_day Distribution',fontsize=15,fontweight ='bold')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='p_day',data=data, hue= 'label')
plt.show()

# %% [markdown]
# #### Observations:
#
# 1. No significant observation is found from above plot.
#
# #### For payback30:

# %%
plt.figure(figsize=(20,5))
sns.distplot(data['payback30'], bins=100)
plt.show()

# %% [markdown]
# #### Observations:
#
# 1. Range of payback30 is 0 to 25.
#
# #### For p_month:

# %%
f,ax=plt.subplots(1,2,figsize=(20,6))

data['p_month'].value_counts().plot.pie(autopct='%3.1f%%', textprops ={ 'fontweight': 'bold','fontsize':10}, ax=ax[0])
ax[0].set_title('p_month Distribution', fontsize=15,fontweight ='bold')
sns.countplot('p_month',data=data,ax=ax[1])
ax[1].set_title('p_month Distribution',fontsize=15,fontweight ='bold')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='p_month',data=data, hue= 'label')
plt.show()

# %%
pd.crosstab([data.p_month],data["label"],margins=True)
# Out:
# label        0       1     All
# p_month
# 6        13261   69893   83154
# 7        12901   72863   85764
# 8            0   40674   40674
# All      26162  183430  209592

# %% [markdown]
# #### Observations:
#
# 1. Maximum defaulter are from month 6 and 7.
# 2. There are no defaulter for month 8.
#
# #### For maxamnt_loans30:

# %%
f,ax=plt.subplots(1,2,figsize=(20,6))

data['maxamnt_loans30'].value_counts().plot.pie(autopct='%3.1f%%', textprops ={ 'fontweight': 'bold','fontsize':10}, ax=ax[0])
ax[0].set_title('maxamnt_loans30 Distribution', fontsize=15,fontweight ='bold')
sns.countplot('maxamnt_loans30',data=data,ax=ax[1])
ax[1].set_title('maxamnt_loans30 Distribution',fontsize=15,fontweight ='bold')
plt.show()

# %%
plt.figure(figsize=(8,3))
sns.countplot(x='maxamnt_loans30',data=data, hue= 'label')
plt.show()

# %%
pd.crosstab([data.maxamnt_loans30],data["label"],margins=True)
# Out:
# label                0       1     All
# maxamnt_loans30
# 0.0                129    4162    4291
# 6.0              25013  154179  179192
# 12.0              1020   25089   26109
# All              26162  183430  209592

# %% [markdown]
# #### Observations:
#
# 1. Maximum number of people had taken maxamnt_loans30 equal to 6 as the loan amount and the the percentage is 85.5%.
# 2. The number of people had not taken loan in last 30 days is 4291 which is 2.0%.
# 3. Obviously maximum defaulter are from maxamnt_loans30 = 6 group.
#
# #### For maxamnt_loans90:

# %%
f,ax=plt.subplots(1,2,figsize=(20,6))

data['maxamnt_loans90'].value_counts().plot.pie(autopct='%3.1f%%', textprops ={ 'fontweight': 'bold','fontsize':10}, ax=ax[0])
ax[0].set_title('maxamnt_loans90 Distribution', fontsize=15,fontweight ='bold')
sns.countplot('maxamnt_loans90',data=data,ax=ax[1])
ax[1].set_title('maxamnt_loans90 Distribution',fontsize=15,fontweight ='bold')
plt.show()

# %%
pd.crosstab([data.maxamnt_loans90],data["label"],margins=True)
# Out:
# label                0       1     All
# maxamnt_loans90
# 0                    0    2043    2043
# 6                25140  155804  180944
# 12                1022   25583   26605
# All              26162  183430  209592

# %% [markdown]
# #### Observations:
#
# 1. Maximum number of people had taken maxamnt_loans90 equal to 6 as the loan amount and the the percentage is 86.3%.
# 2. The number of people had not taken loan in last 90 days is 2043 which is 1.0%.
# 3. Obviously maximum defaulter are from maxamnt_loans90 = 6 group.
# 4. For maxamnt_loans30= 0, there are defaulter. But for maxamnt_loans90= 0, there are no defaulter.
#
# #### For medianamnt_loans30:

# %%
f,ax=plt.subplots(1,2,figsize=(20,6))

data['medianamnt_loans30'].value_counts().plot.pie(autopct='%3.1f%%', textprops ={ 'fontweight': 'bold','fontsize':10}, ax=ax[0])
ax[0].set_title('medianamnt_loans30 Distribution', fontsize=15,fontweight ='bold')
sns.countplot('medianamnt_loans30',data=data,ax=ax[1])
ax[1].set_title('medianamnt_loans30 Distribution',fontsize=15,fontweight ='bold')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='medianamnt_loans30',data=data, hue= 'label')
plt.show()

# %%
table= pd.crosstab(data['medianamnt_loans30'], data['label'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='barh',stacked=True, figsize=(8,5))
plt.title('Percent of label distribution as per medianamnt_loans30', fontsize=22, fontweight='bold')
plt.show()

# %%
pd.crosstab([data.medianamnt_loans30],data["label"],margins=True)
# Out:
# label                   0       1     All
# medianamnt_loans30
# 0.0                 25202  170242  195444
# 0.5                   440    6098    6538
# 1.0                   520    6629    7149
# 1.5                     0      38      38
# 2.0                     0     420     420
# 3.0                     0       3       3
# All                 26162  183430  209592

# %% [markdown]
# #### Observations:
#
# 1. Maximum medianamnt_loans30 that is Median of amounts of loan taken by the user in last 30 days is 0.0.
# 2. No defaulter for medianamnt_loans30 equal to 1.5,2.0,3.0.
#
# #### For medianamnt_loans90:

# %%
f,ax=plt.subplots(1,2,figsize=(20,6))

data['medianamnt_loans90'].value_counts().plot.pie(autopct='%3.1f%%', textprops ={ 'fontweight': 'bold','fontsize':10}, ax=ax[0])
ax[0].set_title('medianamnt_loans90 Distribution', fontsize=15,fontweight ='bold')
sns.countplot('medianamnt_loans90',data=data,ax=ax[1])
ax[1].set_title('medianamnt_loans90 Distribution',fontsize=15,fontweight ='bold')
plt.show()

# %%
pd.crosstab([data.medianamnt_loans90],data["label"],margins=True)
# Out:
# label                   0       1     All
# medianamnt_loans90
# 0.0                 25230  172193  197423
# 0.5                   447    5221    5668
# 1.0                   485    5687    6172
# 1.5                     0      19      19
# 2.0                     0     307     307
# 3.0                     0       3       3
# All                 26162  183430  209592

# %% [markdown]
# #### Observations:
#
# 1. Maximum medianamnt_loans90 that is Median of amounts of loan taken by the user in last 90 days is 0.0.
# 2. No defaulter for medianamnt_loans90 equal to 1.5,2.0,3.0.
#
# #### For last_rech_amt_ma:

# %%
plt.figure(figsize=(25,8))
sns.countplot(x='last_rech_amt_ma',data=data, hue= 'label')
plt.xticks(rotation=90)
plt.xlabel("last_rech_amt_ma", fontweight= 'bold', fontsize=15)
plt.show()

# %% [markdown]
# #### Observations:
#
# 1. Amount of last recharge of main account is maximum for 770, 1539.
# 2. Max defaulter are from last_rech_amt_ma=0.
#
# #### For cnt_da_rech90:

# %%
plt.figure(figsize=(25,8))
sns.countplot(x='cnt_da_rech90',data=data, hue= 'label')
plt.xticks(rotation=90)
plt.xlabel("cnt_da_rech90", fontweight= 'bold', fontsize=15)
plt.show()

# %% [markdown]
# #### Observations:
#
# 1. Max cnt_da_rech90 is 0.
#
# #### For cnt_loans30:

# %%
f,ax=plt.subplots(1,2,figsize=(20,6))

data['cnt_loans30'].value_counts().plot.pie(autopct='%3.1f%%',  ax=ax[0])
ax[0].set_title('cnt_loans30 Distribution', fontsize=15,fontweight ='bold')
sns.countplot('cnt_loans30',data=data,ax=ax[1])
ax[1].set_title('cnt_loans30 Distribution',fontsize=15,fontweight ='bold')
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='cnt_loans30',data=data, hue= 'label')
plt.show()

# %% [markdown]
# #### Observations:
#
# 1. Maximum number of loans taken by user in last 30 days is 1.
#
# #### For amnt_loans30:

# %%
f,ax=plt.subplots(1,2,figsize=(20,6))

data['amnt_loans30'].value_counts().plot.pie(autopct='%3.1f%%',  ax=ax[0])
ax[0].set_title('amnt_loans30 Distribution', fontsize=15,fontweight ='bold')
sns.countplot('amnt_loans30',data=data,ax=ax[1])
ax[1].set_title('amnt_loans30 Distribution',fontsize=15,fontweight ='bold')
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='amnt_loans30',data=data, hue= 'label')
plt.show()

# %% [markdown]
# #### Observations:
#
# 1. Maximum total amount of loans taken by user in last 30 days is 6.
#
# ### Relation between different features and labels(Multivariate Analysis):

# %%
plt.figure(figsize=(15,5))
sns.boxenplot(x="cnt_loans30",y='amnt_loans30', data=data)
plt.xlabel('Number of loans taken in 30 days',fontsize=15,fontweight ='bold')
plt.ylabel('Amount of loan taken in 30 days',fontsize=15,fontweight ='bold')
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="cnt_loans30",y='amnt_loans30', hue='label', data=data)
plt.xlabel('Number of loans taken in 30 days',fontsize=15,fontweight ='bold')
plt.ylabel('Amount of loan taken in 30 days',fontsize=15,fontweight ='bold')
plt.show()

# %% [markdown]
# #### Observations:
#
# 1. Maximum number of loans taken by the people is 50 and the loan amount is equivalent to 300.
# 2. Minimum number of loans taken by the people is 0.
# 3. No defaulter are there if Number of loans taken in 30 days is in 30 to 50.

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="cnt_loans30",y='payback30', hue='label',  data=data)
plt.xlabel('Number of loans taken in 30 days',fontsize=15,fontweight ='bold')
plt.ylabel('Average payback time in days over last 30 days',fontsize=15,fontweight ='bold')
plt.show()

# %% [markdown]
# #### Obsergvations:
#
# 1. The Average payback time over last 30 days is higher for people who had taken 2 and 3 times the loan in 30 days.
# 2. The users with less number of loan taking are more the defaulters.
# 3. If Number of loans taken in 30 days is increased, the defaulters are decreased.

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="p_day",y='payback30', hue='label',  data=data)
plt.show()

# %%
plt.figure(figsize=(15,4))
sns.boxenplot(x="p_month",y='payback30', data=data,  hue='label')
plt.show()

# %%
plt.figure(figsize=(15,4))
sns.boxenplot(x="medianamnt_loans90",y='payback30', data=data,  hue='label')
plt.show()

# %% [markdown]
# #### Observations:
#
# 1. No specific relation is found from the above plot.

# %%
plt.figure(figsize=(20,5))
sns.lineplot(x="p_day",y='payback90', hue='label',  data=data)
plt.xlabel("Average payback time in days over last 90 days",fontsize=15,fontweight ='bold' )
plt.show()

# %% [markdown]
# #### Observations:
#
# 1. Average payback time in days over last 90 days is higher for Non- defaulter users.

# %% [markdown]
# ### Encoding categorical data:
#
# Here one categorical feature is available wich is msisdn: mobile number of user. No need to keep it as it has no importance to determine label. Let's drop it.

# %%
data.drop(['msisdn'],axis=1,inplace=True)

# %% [markdown]
# No categorical data is present.
#
# ### Outliers Detection and Removal:

# %%
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1
for x in data:
    if plotnumber<=35:
        plt.subplot(9,4,plotnumber)
        sns.boxplot(data[x], color='blue')
        plt.xlabel(x)
    plotnumber+=1
plt.show()

# %%
data.plot(kind ='box', subplots =True , layout =(5,7), figsize = (20,20))
plt.show()

# %% [markdown]
# #### Observations :
# From the previous Boxplot , it is seen that **there are some outiers in numarical featues columns. Let's remove it.**
# But interestingly there are no outliers in lower capping level.
#
# #### Outliers removal by Z score:
#
# Let's take the Z Score =3
#
# Any data with Z Score>3, should to be rejected

# %%
df=data.copy()

# %%
from scipy.stats import zscore
z = np.abs(zscore(data))

# %%
print(np.where(z>3))
# Out:
# (array([    21,     22,     22, ..., 209585, 209586, 209586], dtype=int64), array([15, 15, 32, ..., 28, 26, 30], dtype=int64))

# %%
data1 = data[(z<3).all(axis = 1)]
data1.shape
# Out:
# (160499, 35)

# %%
data.shape
# Out:
# (209592, 35)

# %%
print ("Percentage of data loss",((data.shape[0]- data1.shape[0])/data.shape[0])*100, "%")
# Out:
# Percentage of data loss 23.42312683690217 %

# %% [markdown]
# #### Observations:
#
# Here we can see that a lot of data are lossed by applying z score method on it.
#
# As per problem statement,  **data is expensive and we cannot lose more than 7-8% of the data.**
#
# Let's use **Quantile-based technique.**

# %%
#1st quantile
q1= data. quantile(0.0)
#3rd quantile
q3= data. quantile(0.99)
#IQR
iqr= q3-q1

# %%
data_new = data[~((data < (q1 - 1.5 *iqr)) |(data > (q3 + 1.5 *iqr))).any(axis=1)]
print(data_new.shape)
# Out:
# (198174, 35)

# %%
data.shape
# Out:
# (209592, 35)

# %%
print ("Percentage of data loss",((data.shape[0] - data_new.shape[0])/data.shape[0])*100, '%')
# Out:
# Percentage of data loss 5.447727012481392 %

# %% [markdown]
# #### Observations:
#
# All outliers are removed.

# %% [markdown]
# ### Skewness:

# %%
i=0
plt.figure(figsize=(20,20))
for x in data_new.columns:
    plt.subplot(7,5,i+1)
    sns.distplot(data_new[x], bins=50)
    plt.xlabel(x,fontsize=20)
    i=i+1
plt.tight_layout()

# %%
data_new.skew().sort_values()
# Out:
# label                   -2.271908
# fr_da_rech90             0.000000
# fr_da_rech30             0.000000
# p_day                    0.209468
# p_month                  0.348230
# aon                      0.953359
# maxamnt_loans30          1.248748
# maxamnt_loans90          1.694146
# fr_ma_rech30             2.022702
# fr_ma_rech90             2.282754
# last_rech_amt_ma         2.299548
# cnt_ma_rech30            2.353904
# cnt_loans30              2.502413
# medianamnt_ma_rech30     2.511191
# medianamnt_ma_rech90     2.528494
# cnt_ma_rech90            2.583006
# amnt_loans30             2.643728
# cnt_loans90              2.797465
# amnt_loans90             2.876427
# rental30                 3.099030
# daily_decr30             3.105440
# sumamnt_ma_rech30        3.126539
# sumamnt_ma_rech90        3.170519
# rental90                 3.254858
# daily_decr90             3.271934
# last_rech_date_ma        3.474759
# medianamnt_loans30       4.534407
# ...

# %% [markdown]
# #### Observations:
#
# Skewness is present in all features including target. Let's remove the skewness except label as it is the target variable.
# **Let's use PowerTransformer to transform skewness in features.**

# %%
skew_data = ['aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90','last_rech_date_ma', 'last_rech_date_da',
            'last_rech_amt_ma','cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30','medianamnt_ma_rech30',
            'medianmarechprebal30', 'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
       'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30','cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
       'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90','maxamnt_loans90', 
            'medianamnt_loans90', 'payback30', 'payback90','p_day', 'p_month']

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# %%
data_new[skew_data] = scaler.fit_transform(data_new[skew_data].values)

# %%
data_new.skew().sort_values()
# Out:
# label                  -2.271908
# sumamnt_ma_rech30      -0.314228
# sumamnt_ma_rech90      -0.214062
# medianamnt_ma_rech30   -0.206002
# p_day                  -0.153784
# daily_decr30           -0.130882
# daily_decr90           -0.120816
# last_rech_amt_ma       -0.083886
# medianamnt_ma_rech90   -0.066142
# aon                    -0.056858
# rental30               -0.044562
# rental90               -0.044552
# amnt_loans90           -0.008161
# cnt_ma_rech90          -0.003740
# cnt_ma_rech30          -0.001233
# fr_da_rech90            0.000000
# fr_da_rech30            0.000000
# amnt_loans30            0.002737
# cnt_loans30             0.036997
# last_rech_date_ma       0.041791
# p_month                 0.079282
# cnt_loans90             0.097595
# fr_ma_rech30            0.136359
# fr_ma_rech90            0.143563
# payback90               0.208658
# payback30               0.296427
# maxamnt_loans90         0.367231
# maxamnt_loans30         0.427386
# ...

# %% [markdown]
# #### Observations:
#
# Skewness of most of features is removed.
#
# ### Correlation:

# %%
data_new.corr()
# Out:
#                          label       aon  daily_decr30  daily_decr90  \
# label                 1.000000  0.102185      0.268143      0.270628
# aon                   0.102185  1.000000      0.118006      0.118686
# daily_decr30          0.268143  0.118006      1.000000      0.998269
# daily_decr90          0.270628  0.118686      0.998269      1.000000
# rental30              0.144527  0.084513      0.581151      0.581397
# rental90              0.159672  0.092395      0.637900      0.643209
# last_rech_date_ma     0.067789  0.066388      0.127039      0.131239
# last_rech_date_da     0.027738  0.009568      0.052008      0.052159
# last_rech_amt_ma      0.263310  0.099651      0.377756      0.377242
# cnt_ma_rech30         0.345216  0.040823      0.496305      0.491612
# fr_ma_rech30          0.245368  0.073256      0.300047      0.299273
# sumamnt_ma_rech30     0.358906  0.082927      0.555073      0.549521
# medianamnt_ma_rech30  0.279250  0.099293      0.389906      0.386693
# ...

# %%
plt.subplots(figsize=(25,15))
sns.heatmap(data_new.corr(), annot= True, linecolor= "yellow",  linewidths=2)
plt.show()

# %% [markdown]
# #### Observations:
#
# As are unnecessary columns, let's remove it. It has no correlation with others.

# %%
data_new.drop(['fr_da_rech30','fr_da_rech90' ],axis=1,inplace=True)
data_new.shape
# Out:
# (198174, 33)

# %%
data_new.drop("label", axis=1).corrwith(data_new["label"]).sort_values(ascending=False).plot(kind='bar',
        figsize=(15,6),grid='True',title='feature vs label corr')
plt.show()

# %% [markdown]
# #### Observsations:
#
# sumamnt_ma_rech90, cnt_ma_rech90, sumamnt_ma_rech30, cnt_ma_rech30 are highly corelated with each other.
#
# ### Data Balancing (SMOTE) :
#
# Let's balance the target variable label by SMOTE().

# %%
data_new1= data_new.copy()

# %%
data_new['label'].value_counts()
# Out:
# 1    173461
# 0     24713
# Name: label, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
over = SMOTE()

# splitting data in target and dependent feature
x = data_new.drop(['label'], axis =1)
y = data_new['label']
x,y = over.fit_resample(x,y)
y.value_counts()
# Out:
# 0    173461
# 1    173461
# Name: label, dtype: int64

# %% [markdown]
# ### Checking Multicollinearity:

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif= pd.DataFrame()
vif["VIF"]= [variance_inflation_factor(x.values,i)for i in range(x.shape[1])]
vif["Features"] = x.columns
vif
# Out:
#            VIF              Features
# 0     1.058549                   aon
# 1   757.391427          daily_decr30
# 2   827.561046          daily_decr90
# 3    47.290598              rental30
# 4    51.958829              rental90
# 5     2.894171     last_rech_date_ma
# 6    18.515393     last_rech_date_da
# 7    13.244802      last_rech_amt_ma
# 8    86.890388         cnt_ma_rech30
# 9     2.740724          fr_ma_rech30
# 10  161.943603     sumamnt_ma_rech30
# 11   31.005223  medianamnt_ma_rech30
# 12    3.702393  medianmarechprebal30
# 13  102.293898         cnt_ma_rech90
# 14    2.427200          fr_ma_rech90
# 15  155.561095     sumamnt_ma_rech90
# 16   35.173577  medianamnt_ma_rech90
# 17    3.654441  medianmarechprebal90
# 18    1.984671         cnt_da_rech30
# 19   19.481249         cnt_da_rech90
# 20  218.823732           cnt_loans30
# 21  233.189076          amnt_loans30
# 22    7.760976       maxamnt_loans30
# 23    5.730618    medianamnt_loans30
# ...

# %% [markdown]
# #### Observation:
#
# 1. Multicollinearity present between different features.
#
# Remove this after checking PCA.
#
#
# ### Principal Component Analysis (PCA) :

# %%
x1= x.copy()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
pca = PCA()
scaler= StandardScaler()
x_scale = scaler.fit_transform(x)

# %%
x_pca = pca.fit_transform(x_scale)
plt.figure(figsize=(8,6))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.title('Principal Component Analysis (PCA) graph ')
plt.grid()

# %% [markdown]
# #### Observations:
#
# Here , around 95% variance gives the first 13 component. Let's take the first 13 components.

# %%
pca_new = PCA(n_components=13)
x_scale_new = pca_new.fit_transform(x_scale)
prin_x=pd.DataFrame(x_scale_new )

# %% [markdown]
# ### Final predictions using different Classification ML Models :
#
# #### Find best Random state:

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

from sklearn.linear_model import LogisticRegression

acc_max=0
random_max=0
for i in range(500, 1000):
    x_train,x_test,y_train,y_test = train_test_split(x_scale_new,y,test_size = 0.25, random_state=i)
    log= LogisticRegression()
    log.fit(x_train,y_train)
    y_pred=log.predict(x_test)
    acc= accuracy_score(y_test,y_pred)
    if acc>acc_max:
        acc_max=acc
        random_max=i
        
print('Best accuracy is', acc_max ,'on Random_state', random_max)
# Out:
# Best accuracy is 0.7670729035754229 on Random_state 979

# %% [markdown]
# **Here the best accuracy on Random_state=979, Let's take it.**

# %%
print('Training feature shape:',x_train.shape)
print('Training target shape:',y_train.shape)
print('Test feature shape:',x_test.shape)
print('Test target shape:',y_test.shape)
# Out:
# Training feature shape: (260191, 13)
# Training target shape: (260191,)
# Test feature shape: (86731, 13)
# Test target shape: (86731,)

# %% [markdown]
# ### 1. Using LogisticRegression():

# %%
from sklearn.linear_model import LogisticRegression

x_train,x_test,y_train,y_test = train_test_split(x_scale_new,y,test_size = 0.25, random_state= 979)

log = LogisticRegression()

log.fit(x_train, y_train)

y_pred = log.predict(x_test)

print('accu score : ', accuracy_score(y_test, y_pred))
print ('cof_mat:\n ', confusion_matrix(y_test, y_pred))
print('classification report:\n ', classification_report(y_test, y_pred))

print("-----------")
print("-----------")

print('training score : ', log.score(x_train, y_train))
print('testing score : ', log.score(x_test, y_test))
# Out:
# accu score :  0.7670729035754229
# cof_mat:
#   [[33315 10297]
#  [ 9905 33214]]
# classification report:
#                 precision    recall  f1-score   support
#
#            0       0.77      0.76      0.77     43612
#            1       0.76      0.77      0.77     43119
#
#     accuracy                           0.77     86731
#    macro avg       0.77      0.77      0.77     86731
# weighted avg       0.77      0.77      0.77     86731
#
# -----------
# -----------
# training score :  0.7612330941500667
# testing score :  0.7670729035754229

# %% [markdown]
# ### 2. Using DecisionTreeClassifier()

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)

print('accu score : ', accuracy_score(y_test, y_pred))
print("\n")
print ('cof_mat: ', confusion_matrix(y_test, y_pred))
print("\n")
print('classification report: \n\n', classification_report(y_test, y_pred))

print("-----------")
print("-----------")

print('training score : ', clf.score(x_train, y_train))
print('testing score : ', clf.score(x_test, y_test))
# Out:
# accu score :  0.8728482318894052
#
#
# cof_mat:  [[38844  4768]
#  [ 6260 36859]]
#
#
# classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.86      0.89      0.88     43612
#            1       0.89      0.85      0.87     43119
#
#     accuracy                           0.87     86731
#    macro avg       0.87      0.87      0.87     86731
# weighted avg       0.87      0.87      0.87     86731
#
# -----------
# -----------
# training score :  0.9999807833476178
# testing score :  0.8728482318894052

# %% [markdown]
# ### 3. Using GradientBoostingClassifier():

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbdt= GradientBoostingClassifier()
gbdt.fit(x_train, y_train)

y_pred = gbdt.predict(x_test)


print('accu score : ', accuracy_score(y_test, y_pred))
print("\n")
print ('cof_mat: ', confusion_matrix(y_test, y_pred))
print("\n")
print('classification report: \n\n', classification_report(y_test, y_pred))

print("-----------")
print("-----------")

print('training score : ', gbdt.score(x_train, y_train))
print('testing score : ', gbdt.score(x_test, y_test))
# Out:
# accu score :  0.8009592879132029
#
#
# cof_mat:  [[34834  8778]
#  [ 8485 34634]]
#
#
# classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80     43612
#            1       0.80      0.80      0.80     43119
#
#     accuracy                           0.80     86731
#    macro avg       0.80      0.80      0.80     86731
# weighted avg       0.80      0.80      0.80     86731
#
# -----------
# -----------
# training score :  0.7992666925450919
# testing score :  0.8009592879132029

# %% [markdown]
# ### 4. Using RandomForestClassifier()

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(x_train, y_train)

y_pred = rf.predict(x_test)


print('accu score : ', accuracy_score(y_test, y_pred))
print("\n")
print ('cof_mat: ', confusion_matrix(y_test, y_pred))
print("\n")
print('classification report: ', classification_report(y_test, y_pred))

print("-----------")
print("-----------")

print('training score : ', rf.score(x_train, y_train))
print('testing score : ', rf.score(x_test, y_test))
# Out:
# accu score :  0.9331035039374618
#
#
# cof_mat:  [[41399  2213]
#  [ 3589 39530]]
#
#
# classification report:                precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93     43612
#            1       0.95      0.92      0.93     43119
#
#     accuracy                           0.93     86731
#    macro avg       0.93      0.93      0.93     86731
# weighted avg       0.93      0.93      0.93     86731
#
# -----------
# -----------
# training score :  0.9999769400171412
# testing score :  0.9331035039374618

# %% [markdown]
# ### 5. ExtraTreesClassifier():

# %%
from sklearn.ensemble import ExtraTreesClassifier

etc =ExtraTreesClassifier()
etc.fit(x_train, y_train)

y_pred = etc.predict(x_test)


print('accu score : ', accuracy_score(y_test, y_pred))
print("\n")
print ('cof_mat: ', confusion_matrix(y_test, y_pred))
print("\n")
print('classification report: ', classification_report(y_test, y_pred))

print("-----------")
print("-----------")

print('training score : ', etc.score(x_train, y_train))
print('testing score : ', etc.score(x_test, y_test))
# Out:
# accu score :  0.9472852843850527
#
#
# cof_mat:  [[41961  1651]
#  [ 2921 40198]]
#
#
# classification report:                precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95     43612
#            1       0.96      0.93      0.95     43119
#
#     accuracy                           0.95     86731
#    macro avg       0.95      0.95      0.95     86731
# weighted avg       0.95      0.95      0.95     86731
#
# -----------
# -----------
# training score :  0.9999807833476178
# testing score :  0.9472852843850527

# %% [markdown]
# ### 6. Using AdaBoostClassifier:

# %%
from sklearn.ensemble import AdaBoostClassifier

ada = AdaBoostClassifier()
ada.fit(x_train, y_train)

y_pred = ada.predict(x_test)


print('accu score : ', accuracy_score(y_test, y_pred))
print("\n")
print ('cof_mat: ', confusion_matrix(y_test, y_pred))
print("\n")
print('classification report: ', classification_report(y_test, y_pred))

print("-----------")
print("-----------")

print('training score : ', ada.score(x_train, y_train))
print('testing score : ', ada.score(x_test, y_test))
# Out:
# accu score :  0.77792254211297
#
#
# cof_mat:  [[33704  9908]
#  [ 9353 33766]]
#
#
# classification report:                precision    recall  f1-score   support
#
#            0       0.78      0.77      0.78     43612
#            1       0.77      0.78      0.78     43119
#
#     accuracy                           0.78     86731
#    macro avg       0.78      0.78      0.78     86731
# weighted avg       0.78      0.78      0.78     86731
#
# -----------
# -----------
# training score :  0.7745194876071809
# testing score :  0.77792254211297

# %% [markdown]
# ### Cross Validtion:

# %%
from sklearn.model_selection import cross_val_score


all_models = [log, clf, gbdt, rf, etc, ada ]

for i in all_models:
    cvscore = cross_val_score(i, x_scale_new,y, cv =5)
    print('Cross Validation Score of :',i)
    print("\n Cross Validation Score : " ,cvscore)
    print("\nMean CV Score :",cvscore.mean())
    print("\nStd deviation :",cvscore.std())
    print("\n-----------")
    print("-----------")
# Out:
# Cross Validation Score of : LogisticRegression()
#
#  Cross Validation Score :  [0.76065432 0.76173525 0.7624092  0.76353338 0.76570967]
#
# Mean CV Score : 0.7628083639180058
#
# Std deviation : 0.0017259238241837253
#
# -----------
# -----------
# Cross Validation Score of : DecisionTreeClassifier()
#
#  Cross Validation Score :  [0.87536211 0.87601067 0.87485587 0.87572063 0.87579269]
#
# Mean CV Score : 0.8755483933679953
#
# Std deviation : 0.00040430788370536167
#
# -----------
# -----------
# Cross Validation Score of : GradientBoostingClassifier()
#
#  Cross Validation Score :  [0.79283707 0.79792462 0.79835409 0.80064568 0.80302375]
#
# Mean CV Score : 0.7985570426562549
#
# Std deviation : 0.003390373265568803
#
# -----------
# -----------
# Cross Validation Score of : RandomForestClassifier()
#
#  Cross Validation Score :  [0.93246379 0.93681631 0.93546062 0.93644068 0.93641185]
#
# Mean CV Score : 0.9355186519079218
#
# Std deviation : 0.00159169239555621
#
# -----------
# ...

# %% [markdown]
# #### Observations:
#
# #### Among 7 classification models  ExtraTreesClassifier() gives good accuracy and maximum f1 score along with a good  Cross-validation score.
#
# ## Let's plot AUC-ROC Curve.
#
# Plotting ROC AUC Curve to choose best model

# %%
log.fit(x_train, y_train)
clf.fit(x_train, y_train)
gbdt.fit(x_train, y_train)
rf.fit(x_train, y_train)
etc.fit(x_train, y_train)
ada.fit(x_train, y_train)
print ("All model are trained")
# Out:
# All model are trained

# %%
log.fit(x_test, y_test)
clf.fit(x_test, y_test)
gbdt.fit(x_test, y_test)
rf.fit(x_test, y_test)
etc.fit(x_test, y_test)
ada.fit(x_test, y_test)
print ("All model are tested")

# %%
from sklearn.metrics import plot_roc_curve

disp = plot_roc_curve(clf, x_train, y_train)

plot_roc_curve(log, x_train, y_train, ax=disp.ax_)
plot_roc_curve(gbdt, x_train, y_train, ax=disp.ax_)
plot_roc_curve(rf, x_train, y_train, ax=disp.ax_)
plot_roc_curve(etc, x_train, y_train, ax=disp.ax_)
plot_roc_curve(ada, x_train, y_train, ax=disp.ax_)

plt.show()

# %%
from sklearn.metrics import plot_roc_curve

disp = plot_roc_curve(clf, x_test, y_test)

plot_roc_curve(log, x_test, y_test, ax=disp.ax_)
plot_roc_curve(gbdt, x_test, y_test, ax=disp.ax_)
plot_roc_curve(rf,x_test, y_test, ax=disp.ax_)
plot_roc_curve(etc, x_test, y_test, ax=disp.ax_)
plot_roc_curve(ada, x_test, y_test, ax=disp.ax_)

plt.show()

# %% [markdown]
# #### Observations:
#
# Here ExtraTreesClassifier gives best AUC score for training and testing dataset. **So it is the final model for this dataset.**
#
# ### Hyper Parameter Tuning:
#
# Let's do hyperparameter tuning on Extra trees classifier.

# %%
from sklearn.model_selection import GridSearchCV
params = { 'criterion' : ["gini", "entropy","log_loss"] }

etc_grd = GridSearchCV(etc, param_grid = params, cv=3)

etc_grd.fit(x_train, y_train)
print('best params : ', etc_grd.best_params_)
# Out:
# best params :  {'criterion': 'gini'}

# %%
grid_etc_best = etc_grd.best_estimator_
grid_etc_best.fit(x_train, y_train)

y_pred = grid_etc_best.predict(x_test)

print('accu score : ', accuracy_score(y_test, y_pred))
print("\n")
print ('cof_mat: ', confusion_matrix(y_test, y_pred))
print("\n")
print('classification report: \n', classification_report(y_test, y_pred))

print("-----------")
print("-----------")


print('training score : ', grid_etc_best.score(x_train, y_train))
print('testing score : ', grid_etc_best.score(x_test, y_test))
# Out:
# accu score :  0.9475274123439139
#
#
# cof_mat:  [[41959  1653]
#  [ 2898 40221]]
#
#
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95     43612
#            1       0.96      0.93      0.95     43119
#
#     accuracy                           0.95     86731
#    macro avg       0.95      0.95      0.95     86731
# weighted avg       0.95      0.95      0.95     86731
#
# -----------
# -----------
# training score :  0.9999807833476178
# testing score :  0.9475274123439139

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_roc_curve
disp = plot_roc_curve(grid_etc_best,x_test,y_test)   
plt.title('AOC-ROC Curve of Final Model',fontsize=15,fontweight='bold')
plt.show()
auc_score = roc_auc_score(y_test, grid_etc_best.predict(x_test))
print('Final AUC Score is: \n\n',auc_score)
# Out:
# Final AUC Score is:
#
#  0.9474441184768293

# %% [markdown]
# #### Observations:
#
# Here accuracy score is slightly improved after using hyperparameter tuning. First, accueacy was 0.9472852843850527, but after applying hyper parameter tuning it is 0.9475274123439139.
#
# ## Final Model:

# %%
y_pred = grid_etc_best.predict(x_test)
y_pred
# Out:
# array([1, 1, 0, ..., 1, 1, 1], dtype=int64)

# %% [markdown]
# ### confusion matrix

# %%
conf = confusion_matrix (y_test, y_pred)

fig , ax = plt.subplots(figsize=(6,6))
sns.heatmap(conf, annot = True, fmt = ".0f")
plt.show()

# %% [markdown]
# ### Load the model:

# %%
import pickle
pickle.dump(grid_etc_best, open("Micro_Credit_Defaulter_Classification_model", "wb"))
load_Micro_Credit_Defaulter_Classification_model= pickle.load(open("Micro_Credit_Defaulter_Classification_model", "rb"))

# %%
y_pred = load_Micro_Credit_Defaulter_Classification_model.predict(x_test)

y_test = np.array(y_test)
data_prediction_by_model = pd.DataFrame()
data_prediction_by_model["Predicted Values"] = y_pred
data_prediction_by_model["Actual Values"] = y_test
data_prediction_by_model.sample(n=6)
# Out:
#        Predicted Values  Actual Values
# 35196                 0              0
# 21377                 0              0
# 44845                 1              1
# 32795                 0              0
# 400                   0              0
# 79787                 0              0
